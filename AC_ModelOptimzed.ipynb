# %%
import optuna
import gymnasium as gym
import numpy as np
import pandas as pd
from stable_baselines3 import A2C
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
from sklearn.preprocessing import MinMaxScaler

# %%
# Load Tesla stock data
data = pd.read_csv('tesla.csv', parse_dates=['Date'], index_col='Date')

# %%
# Convert 'Volume' column to numeric by removing commas
data['Volume'] = data['Volume'].replace(',', '', regex=True).astype(float)

# %%
# Feature Engineering
data['SMA_10'] = data['Close'].rolling(window=10).mean()
data['EMA_10'] = data['Close'].ewm(span=10, adjust=False).mean()
data['Daily_Return'] = data['Close'].pct_change()
data['Volatility'] = data['Daily_Return'].rolling(window=10).std()

# %%
def compute_rsi(data, window=14):
    delta = data.diff()
    gain = (delta.where(delta > 0, 0)).rolling(window=window).mean()
    loss = (-delta.where(delta < 0, 0)).rolling(window=window).mean()
    rs = gain / loss
    return 100 - (100 / (1 + rs))

data['RSI'] = compute_rsi(data['Close'])
data.dropna(inplace=True)

# %%
# Normalize Data
scaler = MinMaxScaler()
scaled_features = scaler.fit_transform(data[['Open', 'High', 'Low', 'Close', 'Volume', 'SMA_10', 'EMA_10', 'Volatility', 'RSI']])
scaled_data = pd.DataFrame(scaled_features, columns=['Open', 'High', 'Low', 'Close', 'Volume', 'SMA_10', 'EMA_10', 'Volatility', 'RSI'])

# %%
# Define custom TradingEnv
class TradingEnv(gym.Env):
    def __init__(self, data, initial_balance=10000):
        super(TradingEnv, self).__init__()
        self.data = data
        self.initial_balance = initial_balance
        self.current_step = 0
        self.balance = initial_balance
        self.position = 0  # No position initially
        self.previous_price = 0
        self.action_space = gym.spaces.Discrete(3)
        self.observation_space = gym.spaces.Box(low=0, high=1, shape=(self.data.shape[1],), dtype=np.float32)

    def reset(self, seed=None, options=None):
        self.current_step = 0
        self.balance = self.initial_balance
        self.position = 0
        self.previous_price = 0
        return self.data.iloc[self.current_step].values, {}

    def step(self, action):
        current_price = self.data['Close'].iloc[self.current_step]
        reward = 0
        if action == 1:  # Buy
            if self.position == 0:
                self.position = 1
                self.previous_price = current_price
        elif action == 2:  # Sell
            if self.position == 1:
                reward = current_price - self.previous_price
                self.position = 0
        self.current_step += 1
        done = self.current_step >= len(self.data) - 1
        reward += self.position * (current_price - self.previous_price)
        obs = self.data.iloc[self.current_step].values
        return obs, reward, done, {}, {}

    def render(self):
        print(f'Step: {self.current_step}, Balance: {self.balance}, Position: {self.position}')

# Hyperparameter tuning with Optuna
def objective(trial):
    env = DummyVecEnv([lambda: TradingEnv(scaled_data)])
    env = VecNormalize(env, norm_obs=True, norm_reward=True, clip_obs=10.0)
    learning_rate = trial.suggest_loguniform('learning_rate', 1e-5, 1e-2)
    gamma = trial.suggest_float('gamma', 0.95, 0.99)
    ent_coef = trial.suggest_float('ent_coef', 0.0, 0.1)
    vf_coef = trial.suggest_float('vf_coef', 0.25, 0.75)
    n_steps = trial.suggest_int('n_steps', 5, 50)
    model = A2C("MlpPolicy", env, learning_rate=learning_rate, gamma=gamma,
                ent_coef=ent_coef, vf_coef=vf_coef, n_steps=n_steps, verbose=0)
    model.learn(total_timesteps=50000)
    total_reward = 0
    obs = env.reset()
    for _ in range(1000):
        action, _ = model.predict(obs)
        obs, reward, done, _ = env.step(action)
        total_reward += reward
        if done:
            break
    return total_reward

# %%
# Hyperparameter tuning with Optuna
def objective(trial):
    env = DummyVecEnv([lambda: TradingEnv(scaled_data)])
    env = VecNormalize(env, norm_obs=True, norm_reward=True, clip_obs=10.0)
    learning_rate = trial.suggest_loguniform('learning_rate', 1e-5, 1e-2)
    gamma = trial.suggest_float('gamma', 0.95, 0.99)
    ent_coef = trial.suggest_float('ent_coef', 0.0, 0.1)
    vf_coef = trial.suggest_float('vf_coef', 0.25, 0.75)
    n_steps = trial.suggest_int('n_steps', 5, 50)
    model = A2C("MlpPolicy", env, learning_rate=learning_rate, gamma=gamma,
                ent_coef=ent_coef, vf_coef=vf_coef, n_steps=n_steps, verbose=0)
    model.learn(total_timesteps=50000)
    total_reward = 0
    obs = env.reset()
    for _ in range(1000):
        action, _ = model.predict(obs)
        obs, reward, done, _ = env.step(action)
        total_reward += reward
        if done:
            break
    return total_reward

# %%
# Run Optuna optimization
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=20)
# Out:
# [I 2025-02-13 12:38:15,000] A new study created in memory with name: no-name-c09e2979-6869-4f5a-ae9c-923c24d33323
# C:\Users\goel\AppData\Local\Temp\ipykernel_1620\2309285215.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-5, 1e-2)
# C:\Users\goel\anaconda3\ANACONDA\Lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:150: UserWarning: You are trying to run A2C on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# [I 2025-02-13 12:44:50,551] Trial 0 finished with value: 3.1886165142059326 and parameters: {'learning_rate': 0.0016390926207022957, 'gamma': 0.9591441785353568, 'ent_coef': 0.051842759692572606, 'vf_coef': 0.6593832144226704, 'n_steps': 35}. Best is trial 0 with value: 3.1886165142059326.
# C:\Users\goel\AppData\Local\Temp\ipykernel_1620\2309285215.py:5: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-5, 1e-2)
# [I 2025-02-13 12:51:29,182] Trial 1 finished with value: 1.668079137802124 and parameters: {'learning_rate': 9.755887521264482e-05, 'gamma': 0.9678650182793849, 'ent_coef': 0.03472316820020021, 'vf_coef': 0.7325635983587409, 'n_steps': 38}. Best is trial 0 with value: 3.1886165142059326.
# [I 2025-02-13 12:57:49,213] Trial 2 finished with value: -1.1930981874465942 and parameters: {'learning_rate': 1.733264094542455e-05, 'gamma': 0.9543952674358376, 'ent_coef': 0.06281272475875657, 'vf_coef': 0.45861582043535976, 'n_steps': 25}. Best is trial 0 with value: 3.1886165142059326.
# [I 2025-02-13 13:04:09,754] Trial 3 finished with value: 5.613272666931152 and parameters: {'learning_rate': 0.00044480636537872387, 'gamma': 0.9551055705222165, 'ent_coef': 0.09135252851761609, 'vf_coef': 0.42238527641742735, 'n_steps': 41}. Best is trial 3 with value: 5.613272666931152.
# [I 2025-02-13 13:10:11,543] Trial 4 finished with value: -3.2159194946289062 and parameters: {'learning_rate': 1.3810339898598098e-05, 'gamma': 0.9747956221090525, 'ent_coef': 0.06346276545925657, 'vf_coef': 0.7363310183544782, 'n_steps': 23}. Best is trial 3 with value: 5.613272666931152.
# [I 2025-02-13 13:16:03,440] Trial 5 finished with value: 6.063495635986328 and parameters: {'learning_rate': 0.0008623333630239022, 'gamma': 0.9802738220069221, 'ent_coef': 0.03752781950523218, 'vf_coef': 0.3018476754341575, 'n_steps': 24}. Best is trial 5 with value: 6.063495635986328.
# [I 2025-02-13 13:21:30,031] Trial 6 finished with value: 3.0557899475097656 and parameters: {'learning_rate': 0.00015083536710043264, 'gamma': 0.971611625808261, 'ent_coef': 0.04592321167012418, 'vf_coef': 0.4898847924090863, 'n_steps': 38}. Best is trial 5 with value: 6.063495635986328.
# [I 2025-02-13 13:27:46,860] Trial 7 finished with value: 2.920360565185547 and parameters: {'learning_rate': 0.0017192021921713253, 'gamma': 0.958222027716066, 'ent_coef': 0.09430583949664527, 'vf_coef': 0.5750005109325321, 'n_steps': 10}. Best is trial 5 with value: 6.063495635986328.
# [I 2025-02-13 14:01:44,044] Trial 8 finished with value: 1.3088431358337402 and parameters: {'learning_rate': 7.813412996843514e-05, 'gamma': 0.9575799758454201, 'ent_coef': 0.04214982269008345, 'vf_coef': 0.6902058060172706, 'n_steps': 36}. Best is trial 5 with value: 6.063495635986328.
# [I 2025-02-13 14:07:53,795] Trial 9 finished with value: 4.740922927856445 and parameters: {'learning_rate': 0.00037802788390627767, 'gamma': 0.9626464509075944, 'ent_coef': 0.07343057855959019, 'vf_coef': 0.6241077772952215, 'n_steps': 11}. Best is trial 5 with value: 6.063495635986328.
# [I 2025-02-13 14:13:16,521] Trial 10 finished with value: -5.73102331161499 and parameters: {'learning_rate': 0.0076550123442538105, 'gamma': 0.9867967115600091, 'ent_coef': 0.003610821779138018, 'vf_coef': 0.2593810913603173, 'n_steps': 50}. Best is trial 5 with value: 6.063495635986328.
# [I 2025-02-13 14:18:54,651] Trial 11 finished with value: 5.056352615356445 and parameters: {'learning_rate': 0.0007374812022253581, 'gamma': 0.9813508541020401, 'ent_coef': 0.0197992565724779, 'vf_coef': 0.3379720907094062, 'n_steps': 49}. Best is trial 5 with value: 6.063495635986328.
# [I 2025-02-13 14:24:25,817] Trial 12 finished with value: 1.675218939781189 and parameters: {'learning_rate': 0.0039762361581854805, 'gamma': 0.9796446582705568, 'ent_coef': 0.09575615355115266, 'vf_coef': 0.39522810227545757, 'n_steps': 19}. Best is trial 5 with value: 6.063495635986328.
# [I 2025-02-13 14:29:54,295] Trial 13 finished with value: 1.166637659072876 and parameters: {'learning_rate': 0.0004577420673476114, 'gamma': 0.9503172680318953, 'ent_coef': 0.08044054370408593, 'vf_coef': 0.2731295632885472, 'n_steps': 32}. Best is trial 5 with value: 6.063495635986328.
# [I 2025-02-13 14:35:06,775] Trial 14 finished with value: 7.200194835662842 and parameters: {'learning_rate': 0.001015746616434791, 'gamma': 0.9893254401113662, 'ent_coef': 0.026632582716908267, 'vf_coef': 0.3811625028721961, 'n_steps': 44}. Best is trial 14 with value: 7.200194835662842.
# [I 2025-02-16 17:05:04,910] Trial 15 finished with value: 5.452633857727051 and parameters: {'learning_rate': 0.0014233856085013503, 'gamma': 0.987465114699858, 'ent_coef': 0.026773259971214675, 'vf_coef': 0.3378893295260822, 'n_steps': 28}. Best is trial 14 with value: 7.200194835662842.
# [I 2025-02-16 17:11:23,937] Trial 16 finished with value: 3.106783628463745 and parameters: {'learning_rate': 0.004295666791613466, 'gamma': 0.9898077702779178, 'ent_coef': 0.01214303942844859, 'vf_coef': 0.34831657719047443, 'n_steps': 18}. Best is trial 14 with value: 7.200194835662842.
# [I 2025-02-16 17:17:21,818] Trial 17 finished with value: 0.3928178548812866 and parameters: {'learning_rate': 0.00018070473906303764, 'gamma': 0.9820441472771219, 'ent_coef': 0.028565869572304763, 'vf_coef': 0.5473766328795431, 'n_steps': 42}. Best is trial 14 with value: 7.200194835662842.
# [I 2025-02-16 17:24:04,750] Trial 18 finished with value: 0.1581285297870636 and parameters: {'learning_rate': 0.0008565934180961381, 'gamma': 0.977426554388632, 'ent_coef': 0.0006101997843887264, 'vf_coef': 0.3905210986720629, 'n_steps': 16}. Best is trial 14 with value: 7.200194835662842.
# [I 2025-02-16 17:29:40,599] Trial 19 finished with value: 1.4155919551849365 and parameters: {'learning_rate': 5.061358867857759e-05, 'gamma': 0.9843850325591759, 'ent_coef': 0.01680442013632237, 'vf_coef': 0.29897129934963984, 'n_steps': 30}. Best is trial 14 with value: 7.200194835662842.

# %%
# Train final model with best hyperparameters
best_params = study.best_params
env = DummyVecEnv([lambda: TradingEnv(scaled_data)])
env = VecNormalize(env, norm_obs=True, norm_reward=True, clip_obs=10.0)

best_model = A2C("MlpPolicy", env, **best_params, verbose=1, device='cpu')
best_model.learn(total_timesteps=500000)
# Out:
# Using cpu device
# ------------------------------------
# | time/                 |          |
# |    fps                | 388      |
# |    iterations         | 100      |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 4400     |
# | train/                |          |
# |    entropy_loss       | -1.08    |
# |    explained_variance | -0.097   |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 99       |
# |    policy_loss        | 0.0239   |
# |    value_loss         | 0.0189   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 390      |
# |    iterations         | 200      |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 8800     |
# | train/                |          |
# |    entropy_loss       | -1.06    |
# |    explained_variance | 0.297    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 199      |
# |    policy_loss        | 0.107    |
# |    value_loss         | 0.0834   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 397      |
# |    iterations         | 300      |
# |    time_elapsed       | 33       |
# |    total_timesteps    | 13200    |
# | train/                |          |
# |    entropy_loss       | -1.01    |
# |    explained_variance | 0.356    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 299      |
# |    policy_loss        | 0.0503   |
# |    value_loss         | 0.0063   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 399      |
# |    iterations         | 400      |
# |    time_elapsed       | 44       |
# |    total_timesteps    | 17600    |
# | train/                |          |
# |    entropy_loss       | -0.991   |
# |    explained_variance | 0.133    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 399      |
# |    policy_loss        | 0.00563  |
# |    value_loss         | 0.0151   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 402      |
# |    iterations         | 500      |
# |    time_elapsed       | 54       |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -0.993   |
# |    explained_variance | -0.0736  |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 499      |
# |    policy_loss        | -0.199   |
# |    value_loss         | 0.0591   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 396      |
# |    iterations         | 600      |
# |    time_elapsed       | 66       |
# |    total_timesteps    | 26400    |
# | train/                |          |
# |    entropy_loss       | -0.902   |
# |    explained_variance | 0.735    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 599      |
# |    policy_loss        | -0.0795  |
# |    value_loss         | 0.0386   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 394      |
# |    iterations         | 700      |
# |    time_elapsed       | 78       |
# |    total_timesteps    | 30800    |
# | train/                |          |
# |    entropy_loss       | -0.952   |
# |    explained_variance | -0.0607  |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 699      |
# |    policy_loss        | -0.546   |
# |    value_loss         | 0.477    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 388      |
# |    iterations         | 800      |
# |    time_elapsed       | 90       |
# |    total_timesteps    | 35200    |
# | train/                |          |
# |    entropy_loss       | -0.952   |
# |    explained_variance | 0.144    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 799      |
# |    policy_loss        | -0.443   |
# |    value_loss         | 0.242    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 384      |
# |    iterations         | 900      |
# |    time_elapsed       | 103      |
# |    total_timesteps    | 39600    |
# | train/                |          |
# |    entropy_loss       | -0.8     |
# |    explained_variance | 0.396    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 899      |
# |    policy_loss        | 0.417    |
# |    value_loss         | 0.593    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 386      |
# |    iterations         | 1000     |
# |    time_elapsed       | 113      |
# |    total_timesteps    | 44000    |
# | train/                |          |
# |    entropy_loss       | -0.895   |
# |    explained_variance | -1.23    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 999      |
# |    policy_loss        | -0.364   |
# |    value_loss         | 0.305    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 386      |
# |    iterations         | 1100     |
# |    time_elapsed       | 125      |
# |    total_timesteps    | 48400    |
# | train/                |          |
# |    entropy_loss       | -0.89    |
# |    explained_variance | -0.853   |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 1099     |
# |    policy_loss        | 0.165    |
# |    value_loss         | 0.0948   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 388      |
# |    iterations         | 1200     |
# |    time_elapsed       | 135      |
# |    total_timesteps    | 52800    |
# | train/                |          |
# |    entropy_loss       | -0.767   |
# |    explained_variance | 0.382    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 1199     |
# |    policy_loss        | -0.122   |
# |    value_loss         | 0.166    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 388      |
# |    iterations         | 1300     |
# |    time_elapsed       | 147      |
# |    total_timesteps    | 57200    |
# | train/                |          |
# |    entropy_loss       | -0.815   |
# |    explained_variance | 0.615    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 1299     |
# |    policy_loss        | -0.0233  |
# |    value_loss         | 0.115    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 389      |
# |    iterations         | 1400     |
# |    time_elapsed       | 158      |
# |    total_timesteps    | 61600    |
# | train/                |          |
# |    entropy_loss       | -0.621   |
# |    explained_variance | -0.631   |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 1399     |
# |    policy_loss        | -0.337   |
# |    value_loss         | 0.335    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 390      |
# |    iterations         | 1500     |
# |    time_elapsed       | 169      |
# |    total_timesteps    | 66000    |
# | train/                |          |
# |    entropy_loss       | -0.826   |
# |    explained_variance | -0.115   |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 1499     |
# |    policy_loss        | -0.501   |
# |    value_loss         | 0.842    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 391      |
# |    iterations         | 1600     |
# |    time_elapsed       | 179      |
# |    total_timesteps    | 70400    |
# | train/                |          |
# |    entropy_loss       | -0.811   |
# |    explained_variance | -0.215   |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 1599     |
# |    policy_loss        | -0.363   |
# |    value_loss         | 0.331    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 391      |
# |    iterations         | 1700     |
# |    time_elapsed       | 190      |
# |    total_timesteps    | 74800    |
# | train/                |          |
# |    entropy_loss       | -0.809   |
# |    explained_variance | -0.868   |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 1699     |
# |    policy_loss        | 0.0571   |
# |    value_loss         | 0.0292   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 389      |
# |    iterations         | 1800     |
# |    time_elapsed       | 203      |
# |    total_timesteps    | 79200    |
# | train/                |          |
# |    entropy_loss       | -0.782   |
# |    explained_variance | -0.458   |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 1799     |
# |    policy_loss        | -0.903   |
# |    value_loss         | 2.83     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 389      |
# |    iterations         | 1900     |
# |    time_elapsed       | 214      |
# |    total_timesteps    | 83600    |
# | train/                |          |
# |    entropy_loss       | -0.635   |
# |    explained_variance | 0.635    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 1899     |
# |    policy_loss        | -0.178   |
# |    value_loss         | 0.388    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 390      |
# |    iterations         | 2000     |
# |    time_elapsed       | 225      |
# |    total_timesteps    | 88000    |
# | train/                |          |
# |    entropy_loss       | -0.632   |
# |    explained_variance | 0.829    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 1999     |
# |    policy_loss        | 0.0756   |
# |    value_loss         | 0.0298   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 390      |
# |    iterations         | 2100     |
# |    time_elapsed       | 236      |
# |    total_timesteps    | 92400    |
# | train/                |          |
# |    entropy_loss       | -0.78    |
# |    explained_variance | -7.12    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 2099     |
# |    policy_loss        | -0.318   |
# |    value_loss         | 0.175    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 385      |
# |    iterations         | 2200     |
# |    time_elapsed       | 251      |
# |    total_timesteps    | 96800    |
# | train/                |          |
# |    entropy_loss       | -0.802   |
# |    explained_variance | -1.6     |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 2199     |
# |    policy_loss        | -0.0911  |
# |    value_loss         | 0.0594   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 360      |
# |    iterations         | 2300     |
# |    time_elapsed       | 280      |
# |    total_timesteps    | 101200   |
# | train/                |          |
# |    entropy_loss       | -0.803   |
# |    explained_variance | -0.115   |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 2299     |
# |    policy_loss        | -0.287   |
# |    value_loss         | 0.259    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 353      |
# |    iterations         | 2400     |
# |    time_elapsed       | 299      |
# |    total_timesteps    | 105600   |
# | train/                |          |
# |    entropy_loss       | -0.799   |
# |    explained_variance | 0.105    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 2399     |
# |    policy_loss        | 0.166    |
# |    value_loss         | 0.11     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 350      |
# |    iterations         | 2500     |
# |    time_elapsed       | 313      |
# |    total_timesteps    | 110000   |
# | train/                |          |
# |    entropy_loss       | -0.829   |
# |    explained_variance | -0.0493  |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 2499     |
# |    policy_loss        | 1.09     |
# |    value_loss         | 1.77     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 352      |
# |    iterations         | 2600     |
# |    time_elapsed       | 324      |
# |    total_timesteps    | 114400   |
# | train/                |          |
# |    entropy_loss       | -0.745   |
# |    explained_variance | -1.14    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 2599     |
# |    policy_loss        | 0.742    |
# |    value_loss         | 0.909    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 354      |
# |    iterations         | 2700     |
# |    time_elapsed       | 335      |
# |    total_timesteps    | 118800   |
# | train/                |          |
# |    entropy_loss       | -0.857   |
# |    explained_variance | 0.615    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 2699     |
# |    policy_loss        | 0.376    |
# |    value_loss         | 0.354    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 355      |
# |    iterations         | 2800     |
# |    time_elapsed       | 346      |
# |    total_timesteps    | 123200   |
# | train/                |          |
# |    entropy_loss       | -0.809   |
# |    explained_variance | 0.359    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 2799     |
# |    policy_loss        | 0.0854   |
# |    value_loss         | 0.028    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 357      |
# |    iterations         | 2900     |
# |    time_elapsed       | 356      |
# |    total_timesteps    | 127600   |
# | train/                |          |
# |    entropy_loss       | -0.842   |
# |    explained_variance | 0.284    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 2899     |
# |    policy_loss        | -0.618   |
# |    value_loss         | 0.812    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 358      |
# |    iterations         | 3000     |
# |    time_elapsed       | 368      |
# |    total_timesteps    | 132000   |
# | train/                |          |
# |    entropy_loss       | -0.765   |
# |    explained_variance | 0.494    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 2999     |
# |    policy_loss        | -0.0897  |
# |    value_loss         | 0.505    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 360      |
# |    iterations         | 3100     |
# |    time_elapsed       | 378      |
# |    total_timesteps    | 136400   |
# | train/                |          |
# |    entropy_loss       | -0.86    |
# |    explained_variance | 0.626    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 3099     |
# |    policy_loss        | 0.048    |
# |    value_loss         | 0.0205   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 361      |
# |    iterations         | 3200     |
# |    time_elapsed       | 389      |
# |    total_timesteps    | 140800   |
# | train/                |          |
# |    entropy_loss       | -0.766   |
# |    explained_variance | 0.76     |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 3199     |
# |    policy_loss        | 0.275    |
# |    value_loss         | 0.25     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 362      |
# |    iterations         | 3300     |
# |    time_elapsed       | 400      |
# |    total_timesteps    | 145200   |
# | train/                |          |
# |    entropy_loss       | -0.791   |
# |    explained_variance | 0.803    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 3299     |
# |    policy_loss        | -0.287   |
# |    value_loss         | 0.326    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 363      |
# |    iterations         | 3400     |
# |    time_elapsed       | 411      |
# |    total_timesteps    | 149600   |
# | train/                |          |
# |    entropy_loss       | -0.881   |
# |    explained_variance | -1.04    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 3399     |
# |    policy_loss        | -0.407   |
# |    value_loss         | 0.279    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 364      |
# |    iterations         | 3500     |
# |    time_elapsed       | 422      |
# |    total_timesteps    | 154000   |
# | train/                |          |
# |    entropy_loss       | -0.872   |
# |    explained_variance | -5.26    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 3499     |
# |    policy_loss        | -0.87    |
# |    value_loss         | 0.784    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 365      |
# |    iterations         | 3600     |
# |    time_elapsed       | 433      |
# |    total_timesteps    | 158400   |
# | train/                |          |
# |    entropy_loss       | -0.85    |
# |    explained_variance | -4.01    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 3599     |
# |    policy_loss        | -0.77    |
# |    value_loss         | 0.894    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 366      |
# |    iterations         | 3700     |
# |    time_elapsed       | 443      |
# |    total_timesteps    | 162800   |
# | train/                |          |
# |    entropy_loss       | -0.84    |
# |    explained_variance | 0.55     |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 3699     |
# |    policy_loss        | 0.19     |
# |    value_loss         | 0.257    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 366      |
# |    iterations         | 3800     |
# |    time_elapsed       | 456      |
# |    total_timesteps    | 167200   |
# | train/                |          |
# |    entropy_loss       | -0.811   |
# |    explained_variance | 0.456    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 3799     |
# |    policy_loss        | 0.249    |
# |    value_loss         | 0.102    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 366      |
# |    iterations         | 3900     |
# |    time_elapsed       | 468      |
# |    total_timesteps    | 171600   |
# | train/                |          |
# |    entropy_loss       | -0.666   |
# |    explained_variance | 0.00636  |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 3899     |
# |    policy_loss        | 0.822    |
# |    value_loss         | 1.65     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 367      |
# |    iterations         | 4000     |
# |    time_elapsed       | 479      |
# |    total_timesteps    | 176000   |
# | train/                |          |
# |    entropy_loss       | -0.732   |
# |    explained_variance | 0.371    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 3999     |
# |    policy_loss        | 0.476    |
# |    value_loss         | 0.65     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 367      |
# |    iterations         | 4100     |
# |    time_elapsed       | 490      |
# |    total_timesteps    | 180400   |
# | train/                |          |
# |    entropy_loss       | -0.814   |
# |    explained_variance | 0.729    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 4099     |
# |    policy_loss        | -0.0592  |
# |    value_loss         | 0.0421   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 368      |
# |    iterations         | 4200     |
# |    time_elapsed       | 500      |
# |    total_timesteps    | 184800   |
# | train/                |          |
# |    entropy_loss       | -0.775   |
# |    explained_variance | 0.452    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 4199     |
# |    policy_loss        | 0.0463   |
# |    value_loss         | 0.0828   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 369      |
# |    iterations         | 4300     |
# |    time_elapsed       | 511      |
# |    total_timesteps    | 189200   |
# | train/                |          |
# |    entropy_loss       | -0.886   |
# |    explained_variance | -0.511   |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 4299     |
# |    policy_loss        | 0.125    |
# |    value_loss         | 0.0949   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 370      |
# |    iterations         | 4400     |
# |    time_elapsed       | 522      |
# |    total_timesteps    | 193600   |
# | train/                |          |
# |    entropy_loss       | -0.804   |
# |    explained_variance | 0.663    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 4399     |
# |    policy_loss        | -0.243   |
# |    value_loss         | 0.446    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 370      |
# |    iterations         | 4500     |
# |    time_elapsed       | 533      |
# |    total_timesteps    | 198000   |
# | train/                |          |
# |    entropy_loss       | -0.845   |
# |    explained_variance | 0.636    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 4499     |
# |    policy_loss        | 0.272    |
# |    value_loss         | 0.111    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 371      |
# |    iterations         | 4600     |
# |    time_elapsed       | 544      |
# |    total_timesteps    | 202400   |
# | train/                |          |
# |    entropy_loss       | -0.813   |
# |    explained_variance | 0.718    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 4599     |
# |    policy_loss        | -0.269   |
# |    value_loss         | 0.13     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 372      |
# |    iterations         | 4700     |
# |    time_elapsed       | 555      |
# |    total_timesteps    | 206800   |
# | train/                |          |
# |    entropy_loss       | -0.783   |
# |    explained_variance | 0.662    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 4699     |
# |    policy_loss        | -0.124   |
# |    value_loss         | 0.342    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 372      |
# |    iterations         | 4800     |
# |    time_elapsed       | 566      |
# |    total_timesteps    | 211200   |
# | train/                |          |
# |    entropy_loss       | -0.853   |
# |    explained_variance | 0.496    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 4799     |
# |    policy_loss        | -0.0526  |
# |    value_loss         | 0.0241   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 373      |
# |    iterations         | 4900     |
# |    time_elapsed       | 577      |
# |    total_timesteps    | 215600   |
# | train/                |          |
# |    entropy_loss       | -0.836   |
# |    explained_variance | 0.746    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 4899     |
# |    policy_loss        | 0.0727   |
# |    value_loss         | 0.0642   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 374      |
# |    iterations         | 5000     |
# |    time_elapsed       | 588      |
# |    total_timesteps    | 220000   |
# | train/                |          |
# |    entropy_loss       | -0.81    |
# |    explained_variance | 0.041    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 4999     |
# |    policy_loss        | 0.457    |
# |    value_loss         | 1.18     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 374      |
# |    iterations         | 5100     |
# |    time_elapsed       | 599      |
# |    total_timesteps    | 224400   |
# | train/                |          |
# |    entropy_loss       | -0.788   |
# |    explained_variance | 0.893    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 5099     |
# |    policy_loss        | 0.119    |
# |    value_loss         | 0.056    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 374      |
# |    iterations         | 5200     |
# |    time_elapsed       | 610      |
# |    total_timesteps    | 228800   |
# | train/                |          |
# |    entropy_loss       | -0.811   |
# |    explained_variance | 0.583    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 5199     |
# |    policy_loss        | 0.224    |
# |    value_loss         | 0.112    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 375      |
# |    iterations         | 5300     |
# |    time_elapsed       | 621      |
# |    total_timesteps    | 233200   |
# | train/                |          |
# |    entropy_loss       | -0.776   |
# |    explained_variance | 0.264    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 5299     |
# |    policy_loss        | 0.522    |
# |    value_loss         | 0.569    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 376      |
# |    iterations         | 5400     |
# |    time_elapsed       | 631      |
# |    total_timesteps    | 237600   |
# | train/                |          |
# |    entropy_loss       | -0.747   |
# |    explained_variance | 0.586    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 5399     |
# |    policy_loss        | 0.327    |
# |    value_loss         | 0.312    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 376      |
# |    iterations         | 5500     |
# |    time_elapsed       | 642      |
# |    total_timesteps    | 242000   |
# | train/                |          |
# |    entropy_loss       | -0.791   |
# |    explained_variance | 0.379    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 5499     |
# |    policy_loss        | -0.101   |
# |    value_loss         | 0.0718   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 377      |
# |    iterations         | 5600     |
# |    time_elapsed       | 653      |
# |    total_timesteps    | 246400   |
# | train/                |          |
# |    entropy_loss       | -0.775   |
# |    explained_variance | 0.25     |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 5599     |
# |    policy_loss        | 0.45     |
# |    value_loss         | 0.334    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 377      |
# |    iterations         | 5700     |
# |    time_elapsed       | 664      |
# |    total_timesteps    | 250800   |
# | train/                |          |
# |    entropy_loss       | -0.86    |
# |    explained_variance | -3.37    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 5699     |
# |    policy_loss        | 0.377    |
# |    value_loss         | 0.258    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 378      |
# |    iterations         | 5800     |
# |    time_elapsed       | 674      |
# |    total_timesteps    | 255200   |
# | train/                |          |
# |    entropy_loss       | -0.822   |
# |    explained_variance | 0.484    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 5799     |
# |    policy_loss        | 0.117    |
# |    value_loss         | 0.294    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 377      |
# |    iterations         | 5900     |
# |    time_elapsed       | 687      |
# |    total_timesteps    | 259600   |
# | train/                |          |
# |    entropy_loss       | -0.856   |
# |    explained_variance | 0.562    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 5899     |
# |    policy_loss        | -0.17    |
# |    value_loss         | 0.0613   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 378      |
# |    iterations         | 6000     |
# |    time_elapsed       | 697      |
# |    total_timesteps    | 264000   |
# | train/                |          |
# |    entropy_loss       | -0.855   |
# |    explained_variance | 0.719    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 5999     |
# |    policy_loss        | -0.291   |
# |    value_loss         | 0.119    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 378      |
# |    iterations         | 6100     |
# |    time_elapsed       | 709      |
# |    total_timesteps    | 268400   |
# | train/                |          |
# |    entropy_loss       | -0.761   |
# |    explained_variance | 0.558    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 6099     |
# |    policy_loss        | -0.516   |
# |    value_loss         | 0.56     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 378      |
# |    iterations         | 6200     |
# |    time_elapsed       | 720      |
# |    total_timesteps    | 272800   |
# | train/                |          |
# |    entropy_loss       | -0.897   |
# |    explained_variance | -0.164   |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 6199     |
# |    policy_loss        | -0.158   |
# |    value_loss         | 0.0507   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 378      |
# |    iterations         | 6300     |
# |    time_elapsed       | 731      |
# |    total_timesteps    | 277200   |
# | train/                |          |
# |    entropy_loss       | -0.82    |
# |    explained_variance | -1.91    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 6299     |
# |    policy_loss        | -0.815   |
# |    value_loss         | 1.35     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 379      |
# |    iterations         | 6400     |
# |    time_elapsed       | 742      |
# |    total_timesteps    | 281600   |
# | train/                |          |
# |    entropy_loss       | -0.801   |
# |    explained_variance | 0.839    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 6399     |
# |    policy_loss        | -0.7     |
# |    value_loss         | 0.885    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 379      |
# |    iterations         | 6500     |
# |    time_elapsed       | 753      |
# |    total_timesteps    | 286000   |
# | train/                |          |
# |    entropy_loss       | -0.86    |
# |    explained_variance | -0.636   |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 6499     |
# |    policy_loss        | -0.258   |
# |    value_loss         | 0.12     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 379      |
# |    iterations         | 6600     |
# |    time_elapsed       | 764      |
# |    total_timesteps    | 290400   |
# | train/                |          |
# |    entropy_loss       | -0.667   |
# |    explained_variance | 0.305    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 6599     |
# |    policy_loss        | 0.0708   |
# |    value_loss         | 0.0379   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 380      |
# |    iterations         | 6700     |
# |    time_elapsed       | 775      |
# |    total_timesteps    | 294800   |
# | train/                |          |
# |    entropy_loss       | -0.752   |
# |    explained_variance | 0.484    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 6699     |
# |    policy_loss        | 0.0428   |
# |    value_loss         | 0.038    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 380      |
# |    iterations         | 6800     |
# |    time_elapsed       | 786      |
# |    total_timesteps    | 299200   |
# | train/                |          |
# |    entropy_loss       | -0.848   |
# |    explained_variance | 0.688    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 6799     |
# |    policy_loss        | 0.208    |
# |    value_loss         | 0.167    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 380      |
# |    iterations         | 6900     |
# |    time_elapsed       | 797      |
# |    total_timesteps    | 303600   |
# | train/                |          |
# |    entropy_loss       | -0.882   |
# |    explained_variance | 0.604    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 6899     |
# |    policy_loss        | -0.234   |
# |    value_loss         | 0.123    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 380      |
# |    iterations         | 7000     |
# |    time_elapsed       | 809      |
# |    total_timesteps    | 308000   |
# | train/                |          |
# |    entropy_loss       | -0.802   |
# |    explained_variance | 0.277    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 6999     |
# |    policy_loss        | 0.599    |
# |    value_loss         | 0.8      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 380      |
# |    iterations         | 7100     |
# |    time_elapsed       | 821      |
# |    total_timesteps    | 312400   |
# | train/                |          |
# |    entropy_loss       | -0.846   |
# |    explained_variance | 0.0075   |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 7099     |
# |    policy_loss        | 0.235    |
# |    value_loss         | 0.129    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 380      |
# |    iterations         | 7200     |
# |    time_elapsed       | 832      |
# |    total_timesteps    | 316800   |
# | train/                |          |
# |    entropy_loss       | -0.823   |
# |    explained_variance | 0.869    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 7199     |
# |    policy_loss        | -0.258   |
# |    value_loss         | 0.115    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 380      |
# |    iterations         | 7300     |
# |    time_elapsed       | 843      |
# |    total_timesteps    | 321200   |
# | train/                |          |
# |    entropy_loss       | -0.883   |
# |    explained_variance | -0.282   |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 7299     |
# |    policy_loss        | 0.07     |
# |    value_loss         | 0.0233   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 380      |
# |    iterations         | 7400     |
# |    time_elapsed       | 854      |
# |    total_timesteps    | 325600   |
# | train/                |          |
# |    entropy_loss       | -0.905   |
# |    explained_variance | 0.424    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 7399     |
# |    policy_loss        | 0.0753   |
# |    value_loss         | 0.0471   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 381      |
# |    iterations         | 7500     |
# |    time_elapsed       | 865      |
# |    total_timesteps    | 330000   |
# | train/                |          |
# |    entropy_loss       | -0.768   |
# |    explained_variance | 0.802    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 7499     |
# |    policy_loss        | -0.225   |
# |    value_loss         | 0.338    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 381      |
# |    iterations         | 7600     |
# |    time_elapsed       | 876      |
# |    total_timesteps    | 334400   |
# | train/                |          |
# |    entropy_loss       | -0.92    |
# |    explained_variance | 0.57     |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 7599     |
# |    policy_loss        | -0.0343  |
# |    value_loss         | 0.0268   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 381      |
# |    iterations         | 7700     |
# |    time_elapsed       | 887      |
# |    total_timesteps    | 338800   |
# | train/                |          |
# |    entropy_loss       | -0.747   |
# |    explained_variance | -5.49    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 7699     |
# |    policy_loss        | -0.167   |
# |    value_loss         | 0.17     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 382      |
# |    iterations         | 7800     |
# |    time_elapsed       | 898      |
# |    total_timesteps    | 343200   |
# | train/                |          |
# |    entropy_loss       | -0.735   |
# |    explained_variance | 0.464    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 7799     |
# |    policy_loss        | -0.536   |
# |    value_loss         | 1.02     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 382      |
# |    iterations         | 7900     |
# |    time_elapsed       | 909      |
# |    total_timesteps    | 347600   |
# | train/                |          |
# |    entropy_loss       | -0.847   |
# |    explained_variance | -4.58    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 7899     |
# |    policy_loss        | -0.0991  |
# |    value_loss         | 0.206    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 382      |
# |    iterations         | 8000     |
# |    time_elapsed       | 920      |
# |    total_timesteps    | 352000   |
# | train/                |          |
# |    entropy_loss       | -0.744   |
# |    explained_variance | 0.768    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 7999     |
# |    policy_loss        | 0.261    |
# |    value_loss         | 0.131    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 382      |
# |    iterations         | 8100     |
# |    time_elapsed       | 931      |
# |    total_timesteps    | 356400   |
# | train/                |          |
# |    entropy_loss       | -0.818   |
# |    explained_variance | 0.304    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 8099     |
# |    policy_loss        | 0.593    |
# |    value_loss         | 0.59     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 382      |
# |    iterations         | 8200     |
# |    time_elapsed       | 942      |
# |    total_timesteps    | 360800   |
# | train/                |          |
# |    entropy_loss       | -0.759   |
# |    explained_variance | 0.853    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 8199     |
# |    policy_loss        | 0.0635   |
# |    value_loss         | 0.0559   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 382      |
# |    iterations         | 8300     |
# |    time_elapsed       | 954      |
# |    total_timesteps    | 365200   |
# | train/                |          |
# |    entropy_loss       | -0.776   |
# |    explained_variance | 0.848    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 8299     |
# |    policy_loss        | 0.00934  |
# |    value_loss         | 0.0142   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 381      |
# |    iterations         | 8400     |
# |    time_elapsed       | 967      |
# |    total_timesteps    | 369600   |
# | train/                |          |
# |    entropy_loss       | -0.736   |
# |    explained_variance | 0.192    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 8399     |
# |    policy_loss        | 0.581    |
# |    value_loss         | 0.79     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 382      |
# |    iterations         | 8500     |
# |    time_elapsed       | 978      |
# |    total_timesteps    | 374000   |
# | train/                |          |
# |    entropy_loss       | -0.847   |
# |    explained_variance | 0.311    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 8499     |
# |    policy_loss        | 0.0237   |
# |    value_loss         | 0.073    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 382      |
# |    iterations         | 8600     |
# |    time_elapsed       | 988      |
# |    total_timesteps    | 378400   |
# | train/                |          |
# |    entropy_loss       | -0.769   |
# |    explained_variance | 0.599    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 8599     |
# |    policy_loss        | -0.13    |
# |    value_loss         | 0.0293   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 382      |
# |    iterations         | 8700     |
# |    time_elapsed       | 999      |
# |    total_timesteps    | 382800   |
# | train/                |          |
# |    entropy_loss       | -0.842   |
# |    explained_variance | -1.11    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 8699     |
# |    policy_loss        | -0.568   |
# |    value_loss         | 0.439    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 383      |
# |    iterations         | 8800     |
# |    time_elapsed       | 1010     |
# |    total_timesteps    | 387200   |
# | train/                |          |
# |    entropy_loss       | -0.905   |
# |    explained_variance | -0.36    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 8799     |
# |    policy_loss        | 0.291    |
# |    value_loss         | 0.148    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 382      |
# |    iterations         | 8900     |
# |    time_elapsed       | 1022     |
# |    total_timesteps    | 391600   |
# | train/                |          |
# |    entropy_loss       | -0.765   |
# |    explained_variance | 0.557    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 8899     |
# |    policy_loss        | -0.338   |
# |    value_loss         | 0.839    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 383      |
# |    iterations         | 9000     |
# |    time_elapsed       | 1033     |
# |    total_timesteps    | 396000   |
# | train/                |          |
# |    entropy_loss       | -0.904   |
# |    explained_variance | 0.655    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 8999     |
# |    policy_loss        | -0.155   |
# |    value_loss         | 0.0507   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 383      |
# |    iterations         | 9100     |
# |    time_elapsed       | 1044     |
# |    total_timesteps    | 400400   |
# | train/                |          |
# |    entropy_loss       | -0.786   |
# |    explained_variance | 0.71     |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 9099     |
# |    policy_loss        | 0.334    |
# |    value_loss         | 0.237    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 383      |
# |    iterations         | 9200     |
# |    time_elapsed       | 1055     |
# |    total_timesteps    | 404800   |
# | train/                |          |
# |    entropy_loss       | -0.773   |
# |    explained_variance | 0.493    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 9199     |
# |    policy_loss        | -0.871   |
# |    value_loss         | 1.28     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 383      |
# |    iterations         | 9300     |
# |    time_elapsed       | 1066     |
# |    total_timesteps    | 409200   |
# | train/                |          |
# |    entropy_loss       | -0.847   |
# |    explained_variance | 0.553    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 9299     |
# |    policy_loss        | -0.139   |
# |    value_loss         | 0.0782   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 383      |
# |    iterations         | 9400     |
# |    time_elapsed       | 1077     |
# |    total_timesteps    | 413600   |
# | train/                |          |
# |    entropy_loss       | -0.688   |
# |    explained_variance | 0.874    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 9399     |
# |    policy_loss        | 0.212    |
# |    value_loss         | 0.0756   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 384      |
# |    iterations         | 9500     |
# |    time_elapsed       | 1088     |
# |    total_timesteps    | 418000   |
# | train/                |          |
# |    entropy_loss       | -0.764   |
# |    explained_variance | 0.45     |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 9499     |
# |    policy_loss        | -0.308   |
# |    value_loss         | 0.459    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 384      |
# |    iterations         | 9600     |
# |    time_elapsed       | 1099     |
# |    total_timesteps    | 422400   |
# | train/                |          |
# |    entropy_loss       | -0.725   |
# |    explained_variance | 0.877    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 9599     |
# |    policy_loss        | 0.0425   |
# |    value_loss         | 0.0393   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 384      |
# |    iterations         | 9700     |
# |    time_elapsed       | 1110     |
# |    total_timesteps    | 426800   |
# | train/                |          |
# |    entropy_loss       | -0.752   |
# |    explained_variance | 0.89     |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 9699     |
# |    policy_loss        | 0.00707  |
# |    value_loss         | 0.0093   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 384      |
# |    iterations         | 9800     |
# |    time_elapsed       | 1121     |
# |    total_timesteps    | 431200   |
# | train/                |          |
# |    entropy_loss       | -0.634   |
# |    explained_variance | -0.618   |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 9799     |
# |    policy_loss        | -1.13    |
# |    value_loss         | 3.14     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 384      |
# |    iterations         | 9900     |
# |    time_elapsed       | 1132     |
# |    total_timesteps    | 435600   |
# | train/                |          |
# |    entropy_loss       | -0.761   |
# |    explained_variance | 0.588    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 9899     |
# |    policy_loss        | 0.561    |
# |    value_loss         | 0.44     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 384      |
# |    iterations         | 10000    |
# |    time_elapsed       | 1143     |
# |    total_timesteps    | 440000   |
# | train/                |          |
# |    entropy_loss       | -0.806   |
# |    explained_variance | 0.8      |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 9999     |
# |    policy_loss        | 0.116    |
# |    value_loss         | 0.0502   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 384      |
# |    iterations         | 10100    |
# |    time_elapsed       | 1154     |
# |    total_timesteps    | 444400   |
# | train/                |          |
# |    entropy_loss       | -0.791   |
# |    explained_variance | 0.407    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 10099    |
# |    policy_loss        | 0.263    |
# |    value_loss         | 0.11     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 385      |
# |    iterations         | 10200    |
# |    time_elapsed       | 1165     |
# |    total_timesteps    | 448800   |
# | train/                |          |
# |    entropy_loss       | -0.854   |
# |    explained_variance | 0.342    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 10199    |
# |    policy_loss        | -0.972   |
# |    value_loss         | 1.65     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 385      |
# |    iterations         | 10300    |
# |    time_elapsed       | 1176     |
# |    total_timesteps    | 453200   |
# | train/                |          |
# |    entropy_loss       | -0.817   |
# |    explained_variance | 0.396    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 10299    |
# |    policy_loss        | -0.227   |
# |    value_loss         | 0.849    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 385      |
# |    iterations         | 10400    |
# |    time_elapsed       | 1187     |
# |    total_timesteps    | 457600   |
# | train/                |          |
# |    entropy_loss       | -0.815   |
# |    explained_variance | 0.643    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 10399    |
# |    policy_loss        | 0.296    |
# |    value_loss         | 0.141    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 385      |
# |    iterations         | 10500    |
# |    time_elapsed       | 1198     |
# |    total_timesteps    | 462000   |
# | train/                |          |
# |    entropy_loss       | -0.858   |
# |    explained_variance | 0.662    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 10499    |
# |    policy_loss        | 0.0314   |
# |    value_loss         | 0.02     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 385      |
# |    iterations         | 10600    |
# |    time_elapsed       | 1209     |
# |    total_timesteps    | 466400   |
# | train/                |          |
# |    entropy_loss       | -0.746   |
# |    explained_variance | 0.523    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 10599    |
# |    policy_loss        | -0.702   |
# |    value_loss         | 1.56     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 385      |
# |    iterations         | 10700    |
# |    time_elapsed       | 1220     |
# |    total_timesteps    | 470800   |
# | train/                |          |
# |    entropy_loss       | -0.876   |
# |    explained_variance | 0.546    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 10699    |
# |    policy_loss        | -0.0679  |
# |    value_loss         | 0.0252   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 385      |
# |    iterations         | 10800    |
# |    time_elapsed       | 1232     |
# |    total_timesteps    | 475200   |
# | train/                |          |
# |    entropy_loss       | -0.812   |
# |    explained_variance | 0.748    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 10799    |
# |    policy_loss        | -0.114   |
# |    value_loss         | 0.0447   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 385      |
# |    iterations         | 10900    |
# |    time_elapsed       | 1245     |
# |    total_timesteps    | 479600   |
# | train/                |          |
# |    entropy_loss       | -0.738   |
# |    explained_variance | 0.579    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 10899    |
# |    policy_loss        | -0.78    |
# |    value_loss         | 1.46     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 385      |
# |    iterations         | 11000    |
# |    time_elapsed       | 1256     |
# |    total_timesteps    | 484000   |
# | train/                |          |
# |    entropy_loss       | -0.794   |
# |    explained_variance | 0.95     |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 10999    |
# |    policy_loss        | 0.156    |
# |    value_loss         | 0.0657   |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 385      |
# |    iterations         | 11100    |
# |    time_elapsed       | 1268     |
# |    total_timesteps    | 488400   |
# | train/                |          |
# |    entropy_loss       | -0.818   |
# |    explained_variance | 0.373    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 11099    |
# |    policy_loss        | -0.993   |
# |    value_loss         | 1.28     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 385      |
# |    iterations         | 11200    |
# |    time_elapsed       | 1278     |
# |    total_timesteps    | 492800   |
# | train/                |          |
# |    entropy_loss       | -0.748   |
# |    explained_variance | 0.65     |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 11199    |
# |    policy_loss        | 0.587    |
# |    value_loss         | 0.739    |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 385      |
# |    iterations         | 11300    |
# |    time_elapsed       | 1290     |
# |    total_timesteps    | 497200   |
# | train/                |          |
# |    entropy_loss       | -0.777   |
# |    explained_variance | 0.639    |
# |    learning_rate      | 0.00102  |
# |    n_updates          | 11299    |
# |    policy_loss        | 0.323    |
# |    value_loss         | 0.249    |
# ------------------------------------

# %%
# Save the trained model
best_model.save("a2c_trading_model")

# %%
# Test the trained model
obs = env.reset()
total_rewards = 0
for step in range(1000):
    action, _states = best_model.predict(obs)
    obs, reward, done, _ = env.step(action)
    total_rewards += reward
    env.render()
    if done:
        print(f"Final Total Reward: {total_rewards}")
        break
# Out:
# C:\Users\goel\anaconda3\ANACONDA\Lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:243: UserWarning: You tried to call render() but no `render_mode` was passed to the env constructor.
#   warnings.warn("You tried to call render() but no `render_mode` was passed to the env constructor.")
# Final Total Reward: [9.70174]

# %%
# Test the trained model
obs = env.reset()
total_rewards = 0
for step in range(1000):
    action, _states = best_model.predict(obs)
    obs, reward, done, _ = env.step(action)
    total_rewards += reward
    env.render()
    if done:
        print(f"Final Total Reward: {total_rewards}")
        break
# Out:
# C:\Users\goel\anaconda3\ANACONDA\Lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:243: UserWarning: You tried to call render() but no `render_mode` was passed to the env constructor.
#   warnings.warn("You tried to call render() but no `render_mode` was passed to the env constructor.")
# Final Total Reward: [7.2824955]

# %%
# Test the trained model
obs = env.reset()
total_rewards = 0
for step in range(1000):
    action, _states = best_model.predict(obs)
    obs, reward, done, _ = env.step(action)
    total_rewards += reward
    env.render()
    if done:
        print(f"Final Total Reward: {total_rewards}")
        break
# Out:
# C:\Users\goel\anaconda3\ANACONDA\Lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:243: UserWarning: You tried to call render() but no `render_mode` was passed to the env constructor.
#   warnings.warn("You tried to call render() but no `render_mode` was passed to the env constructor.")
# Final Total Reward: [9.483933]

# %%
# Test the trained model
obs = env.reset()
total_rewards = 0
for step in range(1000):
    action, _states = best_model.predict(obs)
    obs, reward, done, _ = env.step(action)
    total_rewards += reward
    env.render()
    if done:
        print(f"Final Total Reward: {total_rewards}")
        break
# Out:
# C:\Users\goel\anaconda3\ANACONDA\Lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:243: UserWarning: You tried to call render() but no `render_mode` was passed to the env constructor.
#   warnings.warn("You tried to call render() but no `render_mode` was passed to the env constructor.")
# Final Total Reward: [8.46559]
