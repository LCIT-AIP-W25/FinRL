# %%
import torch

print("Number of GPU: ", torch.cuda.device_count())
print("GPU Name: ", torch.cuda.get_device_name())
# Out:
# Number of GPU:  1
# GPU Name:  NVIDIA GeForce RTX 4050 Laptop GPU

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
# Out:
# Using device: cuda

# %%
# !pip install wrds
# !pip install swig
# !apt-get update -y -qq && apt-get install -y -qq cmake libopenmpi-dev python3-dev zlib1g-dev libgl1-mesa-glx swig
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
# 'apt-get' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import configparser

# Use ConfigParser instead of SafeConfigParser
parser = configparser.ConfigParser()

#parser = configparser.ConfigParser()

# %%
# !pip install git+https://github.com/AI4Finance-Foundation/FinRL.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
#   Cloning https://github.com/AI4Finance-Foundation/FinRL.git to c:\users\aswin\appdata\local\temp\pip-req-build-cbs7mxav
#   Resolved https://github.com/AI4Finance-Foundation/FinRL.git to commit 3a10805389c07e13e94333e94dcfe9beafce49b0
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Cloning https://github.com/AI4Finance-Foundation/ElegantRL.git to c:\users\aswin\appdata\local\temp\pip-install-tknata2g\elegantrl_62f96a61ff0d4674b2aa8b2414c01bd5
#   Resolved https://github.com/AI4Finance-Foundation/ElegantRL.git to commit 2fa34dd9236498beada8d8443d927970a9de1f7f
#   Preparing metadata (setup.py): started
# ...

# %%
pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
#    ---------------------------------------- 0.0/10.8 MB ? eta -:--:--
#    ---------- ----------------------------- 2.9/10.8 MB 15.2 MB/s eta 0:00:01
#    -------------------- ------------------- 5.5/10.8 MB 14.6 MB/s eta 0:00:01
#    ---------------------------------------- 10.8/10.8 MB 18.2 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import pandas as pd

def list_csv_files(directory):
    """
    List all CSV files in the given directory and display their names.
    
    Args:
        directory (str): The path to the directory containing the CSV files.
        
    Returns:
        list: A list of CSV file names.
    """
    csv_files = [f for f in os.listdir(directory) if f.endswith('.csv')]
    return csv_files

def load_and_combine_data(directory):
    """
    Load all CSV files from the given directory and combine them into a single DataFrame.
    
    Args:
        directory (str): The path to the directory containing the CSV files.
        
    Returns:
        pd.DataFrame: A combined DataFrame of all CSV files.
    """
    combined_df = pd.DataFrame()
    csv_files = list_csv_files(directory)
    for file in csv_files:
        file_path = os.path.join(directory, file)
        df = pd.read_csv(file_path)
        #df['FileName'] = file  # Add a column for the CSV file name
        df['Stock'] = file.replace('.csv', '')  # Add a column for the stock symbol
        combined_df = pd.concat([combined_df, df], ignore_index=True)
    return combined_df

# Example usage
directory_path = "C:/Users/aswin/OneDrive/Desktop/Trading Bot/FinRL/stock_market_data/sp500/csv"
csv_files = list_csv_files(directory_path)

print("CSV Files:")
for file in csv_files:
    print(file)

combined_data = load_and_combine_data(directory_path)

# Display the first few rows of the combined data
print("\nCombined Data:")
print(combined_data.head())
print(combined_data.tail())
# Out:
# CSV Files:
# A.csv
# AAL.csv
# AAP.csv
# AAPL.csv
# ABBV.csv
# ABC.csv
# ABMD.csv
# ABT.csv
# ACN.csv
# ADI.csv
# ADM.csv
# ADP.csv
# ADSK.csv
# AEE.csv
# AEP.csv
# AIZ.csv
# AJG.csv
# AKAM.csv
# ALB.csv
# ALGN.csv
# ALK.csv
# ALLE.csv
# ALTR.csv
# AMAT.csv
# AMD.csv
# AME.csv
# AMGN.csv
# AMP.csv
# AMT.csv
# AMZN.csv
# ANET.csv
# AON.csv
# AOS.csv
# APA.csv
# APD.csv
# APH.csv
# ARE.csv
# ATVI.csv
# AVB.csv
# AVY.csv
# AWK.csv
# AXP.csv
# AZO.csv
# BA.csv
# BAC.csv
# BAX.csv
# BBY.csv
# BDX.csv
# BEN.csv
# BF-A.csv
# BHI.csv
# BIIB.csv
# BIO.csv
# BK.csv
# BLK.csv
# BMRA.csv
# BMY.csv
# BR.csv
# BRK-A.csv
# BSHI.csv
# BSX.csv
# BWA.csv
# BXP.csv
# C.csv
# CAG.csv
# CAH.csv
# CAT.csv
# CB.csv
# CCI.csv
# CDE.csv
# CDNS.csv
# CF.csv
# CFG.csv
# CHD.csv
# CHRW.csv
# CHTR.csv
# CINF.csv
# CL.csv
# CLX.csv
# CME.csv
# CMG.csv
# CMI.csv
# CNC.csv
# CNP.csv
# CNWT.csv
# COO.csv
# COP.csv
# COST.csv
# COTY.csv
# COWN.csv
# CPB.csv
# CPICQ.csv
# CPRT.csv
# CRM.csv
# CSCO.csv
# CTAS.csv
# ...

# %%
# Check the structure of the combined data
print("Data Info:")
print(combined_data.info())

# Check for missing values
print("\nMissing Values:")
print(combined_data.isnull().sum())

# Summary statistics
print("\nSummary Statistics:")
print(combined_data.describe())

# Check unique stocks in the dataset
print("\nUnique Stocks:")
print(combined_data['Stock'].unique())

# Check date range
print("\nDate Range:")
print("Start Date:", combined_data['Date'].min())
print("End Date:", combined_data['Date'].max())
# Out:
# Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3266000 entries, 0 to 3265999
# Data columns (total 8 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   Date            object
#  1   Low             float64
#  2   Open            float64
#  3   Volume          float64
#  4   High            float64
#  5   Close           float64
#  6   Adjusted Close  float64
#  7   Stock           object
# dtypes: float64(6), object(2)
# memory usage: 199.3+ MB
# None
#
# Missing Values:
# Date                 0
# Low               7577
# Open              7577
# Volume            7577
# High              7577
# Close             7577
# Adjusted Close    7577
# Stock                0
# dtype: int64
#
# Summary Statistics:
#                 Low          Open        Volume          High         Close  \
# count  3.258423e+06  3.258423e+06  3.258423e+06  3.258423e+06  3.258423e+06
# mean   3.821284e+02  3.849360e+02  5.064393e+06  3.881214e+02  3.851922e+02
# ...

# %%
# Convert 'Date' column to datetime format
combined_data['Date'] = pd.to_datetime(combined_data['Date'], format='%d-%m-%Y')

# Sort data by 'Stock' and 'Date'
combined_data = combined_data.sort_values(by=['Stock', 'Date'])

# Calculate daily returns for each stock
combined_data['Daily_Return'] = combined_data.groupby('Stock')['Close'].pct_change()

# Drop rows with missing values (e.g., first row for each stock will have NaN for Daily_Return)
combined_data = combined_data.dropna()

# Display the first few rows after preprocessing
print("\nPreprocessed Data:")
print(combined_data.head())
print(combined_data.tail())
# Out:
# Preprocessed Data:
#         Date        Low       Open      Volume       High      Close  \
# 1 1999-11-19  28.478184  30.713518  15234146.0  30.758226  28.880545
# 2 1999-11-22  28.657009  29.551144   6577870.0  31.473534  31.473534
# 3 1999-11-23  28.612303  30.400572   5975611.0  31.205294  28.612303
# 4 1999-11-24  28.612303  28.701717   4843231.0  29.998213  29.372318
# 5 1999-11-26  29.148785  29.238197   1729466.0  29.685265  29.461731
#
#    Adjusted Close Stock  Daily_Return
# 1       24.711119     A     -0.082386
# 2       26.929760     A      0.089783
# 3       24.481602     A     -0.090909
# 4       25.131901     A      0.026563
# 5       25.208408     A      0.003044
#               Date         Low        Open     Volume        High       Close  \
# 3265995 2022-12-06  152.089996  154.220001  1964800.0  155.500000  153.050003
# 3265996 2022-12-07  149.380005  152.960007  2444100.0  153.789993  150.250000
# ...

# %%
pip install matplotlib
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
#    ---------------------------------------- 0.0/7.5 MB ? eta -:--:--
#    ---------------------------------------- 7.5/7.5 MB 42.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 1.5/1.5 MB 39.5 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts fonttools.exe, pyftmerge.exe, pyftsubset.exe and ttx.exe are installed in 'C:\Users\aswin\anaconda3\envs\finrl_env\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
pip install seaborn
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plot daily returns for a specific stock
stock_A_data = combined_data[combined_data['Stock'] == 'A']
plt.figure(figsize=(10, 6))
plt.plot(stock_A_data['Date'], stock_A_data['Daily_Return'], label='Daily Return')
plt.title('Daily Returns for Stock A')
plt.xlabel('Date')
plt.ylabel('Daily Return')
plt.legend()
plt.show()

# Distribution of daily returns
plt.figure(figsize=(10, 6))
sns.histplot(stock_A_data['Daily_Return'], kde=True, bins=50)
plt.title('Distribution of Daily Returns for Stock A')
plt.xlabel('Daily Return')
plt.ylabel('Frequency')
plt.show()

# Correlation matrix for numerical features
correlation_matrix = stock_A_data[['Low', 'Open', 'High', 'Close', 'Volume', 'Daily_Return']].corr()
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix for Stock A')
plt.show()

# %%
# Calculate Moving Averages
combined_data['MA_10'] = combined_data.groupby('Stock')['Close'].transform(lambda x: x.rolling(window=10).mean())
combined_data['MA_50'] = combined_data.groupby('Stock')['Close'].transform(lambda x: x.rolling(window=50).mean())

# Calculate RSI
def calculate_rsi(data, window=14):
    delta = data['Close'].diff()
    gain = (delta.where(delta > 0, 0)).rolling(window=window).mean()
    loss = (-delta.where(delta < 0, 0)).rolling(window=window).mean()
    rs = gain / loss
    rsi = 100 - (100 / (1 + rs))
    return rsi

combined_data['RSI'] = combined_data.groupby('Stock').apply(lambda x: calculate_rsi(x)).reset_index(level=0, drop=True)

# Calculate Volatility (Standard Deviation of Daily Returns)
combined_data['Volatility'] = combined_data.groupby('Stock')['Daily_Return'].transform(lambda x: x.rolling(window=10).std())

# Drop rows with missing values (due to rolling calculations)
combined_data = combined_data.dropna()

# Display the first few rows after feature engineering
print("\nData After Feature Engineering:")
print(combined_data.head())
# Out:
# Data After Feature Engineering:
#          Date        Low       Open     Volume       High      Close  \
# 50 2000-02-01  47.389126  47.389126  1404291.0  51.502148  50.786839
# 51 2000-02-02  51.189198  51.412731  1945177.0  54.721031  54.721031
# 52 2000-02-03  52.798641  53.782188  1779514.0  55.615166  55.615166
# 53 2000-02-04  53.648067  55.615166  1145661.0  55.615166  54.542202
# 54 2000-02-07  54.542202  55.570457  1274277.0  57.224606  56.866955
#
#     Adjusted Close Stock  Daily_Return      MA_10      MA_50        RSI  \
# 50       43.454834     A      0.072710  49.003040  40.462267  57.843141
# 51       46.821064     A      0.077465  49.467990  40.979077  71.236562
# 52       47.586102     A      0.016340  50.156474  41.461910  71.542554
# 53       46.668045     A     -0.019293  50.692954  41.980508  66.237106
# 54       48.657185     A      0.042623  51.479793  42.530400  66.410255
#
#     Volatility
# 50    0.028981
# 51    0.036842
# 52    0.034576
# 53    0.036138
# ...

# %%
pip install scikit-learn
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.comNote: you may need to restart the kernel to use updated packages.
#
# ...
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    ---------------------- ----------------- 5.2/9.3 MB 26.6 MB/s eta 0:00:01
#    ---------------------------------------- 9.3/9.3 MB 32.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/42.2 MB ? eta -:--:--
#    -------- ------------------------------- 8.7/42.2 MB 41.3 MB/s eta 0:00:01
#    ----------------- ---------------------- 18.1/42.2 MB 42.2 MB/s eta 0:00:01
#    ------------------------ --------------- 26.0/42.2 MB 42.2 MB/s eta 0:00:01
#    -------------------------------- ------- 34.6/42.2 MB 42.2 MB/s eta 0:00:01
#    ---------------------------------------- 42.2/42.2 MB 42.0 MB/s eta 0:00:00
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# Normalize features
scaler = MinMaxScaler()
features_to_scale = ['Close', 'Volume', 'MA_10', 'MA_50', 'RSI', 'Volatility']
combined_data[features_to_scale] = scaler.fit_transform(combined_data[features_to_scale])

# Display the first few rows after normalization
print("\nData After Normalization:")
print(combined_data.head())
# Out:
# Data After Normalization:
#          Date        Low       Open    Volume       High     Close  \
# 50 2000-02-01  47.389126  47.389126  0.000189  51.502148  0.000094
# 51 2000-02-02  51.189198  51.412731  0.000262  54.721031  0.000101
# 52 2000-02-03  52.798641  53.782188  0.000240  55.615166  0.000103
# 53 2000-02-04  53.648067  55.615166  0.000154  55.615166  0.000101
# 54 2000-02-07  54.542202  55.570457  0.000172  57.224606  0.000105
#
#     Adjusted Close Stock  Daily_Return     MA_10     MA_50       RSI  \
# 50       43.454834     A      0.072710  0.000092  0.000080  0.578431
# 51       46.821064     A      0.077465  0.000093  0.000081  0.712366
# 52       47.586102     A      0.016340  0.000095  0.000082  0.715426
# 53       46.668045     A     -0.019293  0.000096  0.000083  0.662371
# 54       48.657185     A      0.042623  0.000097  0.000084  0.664103
#
#     Volatility
# 50    0.000009
# 51    0.000012
# 52    0.000011
# 53    0.000011
# 54    0.000012

# %%
# Save preprocessed data to a CSV file
output_file_path = "C:/Users/aswin/OneDrive/Desktop/Trading Bot/FinRL/preprocessed_data_with_features_sp500.csv"
combined_data.to_csv(output_file_path, index=False)
print(f"\nPreprocessed data with features saved to: {output_file_path}")
# Out:
# Preprocessed data with features saved to: C:/Users/aswin/OneDrive/Desktop/Trading Bot/FinRL/preprocessed_data_with_features_sp500.csv

# %%
# Group data by stock
data=pd.read_csv("C:/Users/aswin/OneDrive/Desktop/Trading Bot/FinRL/preprocessed_data_with_features_sp500.csv")
grouped_data = data.groupby('Stock')

# Example: Access data for a specific stock (e.g., 'AAPL')
aapl_data = grouped_data.get_group('AAPL')
print(aapl_data.head())
# Out:
#              Date       Low      Open    Volume      High         Close  \
# 15283  1981-02-25  0.112723  0.112723  0.002626  0.113281  2.090452e-07
# 15284  1981-02-26  0.114397  0.114397  0.001461  0.114955  2.121499e-07
# 15285  1981-02-27  0.118304  0.118304  0.001989  0.119420  2.193961e-07
# 15286  1981-03-02  0.118862  0.118862  0.001585  0.119420  2.204310e-07
# 15287  1981-03-03  0.117188  0.117746  0.002179  0.117746  2.173263e-07
#
#        Adjusted Close Stock  Daily_Return         MA_10         MA_50  \
# 15283        0.087715  AAPL      0.063154  2.144761e-07  2.609416e-07
# 15284        0.089018  AAPL      0.014851  2.138447e-07  2.606551e-07
# 15285        0.092058  AAPL      0.034153  2.141605e-07  2.608755e-07
# 15286        0.092492  AAPL      0.004717  2.151074e-07  2.610077e-07
# 15287        0.091190  AAPL     -0.014084  2.152128e-07  2.609416e-07
#
#             RSI  Volatility
# 15283  0.344827    0.000013
# 15284  0.366665    0.000013
# ...

# %%
pip install joblib
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from joblib import Parallel, delayed

# Define the calculate_var_cvar function in the global scope
def calculate_var_cvar(returns, confidence_level=0.95):
    """
    Calculate Value at Risk (VaR) and Conditional Value at Risk (CVaR).
    
    Args:
        returns (pd.Series): Historical returns of the portfolio.
        confidence_level (float): Confidence level for VaR and CVaR (e.g., 0.95 for 95%).
        
    Returns:
        float: VaR and CVaR values.
    """
    # Sort returns in ascending order
    returns_sorted = returns.sort_values(ascending=True)
    
    # Calculate VaR as the (1 - confidence_level) quantile
    var = returns_sorted.quantile(1 - confidence_level)
    
    # Calculate CVaR as the mean of returns worse than VaR
    cvar = returns_sorted[returns_sorted <= var].mean()
    
    return var, cvar

# Function to calculate metrics for a single stock
def calculate_metrics_for_stock(stock_data):
    stock = stock_data['Stock'].iloc[0]
    returns = stock_data['Daily_Return']
    var, cvar = calculate_var_cvar(returns, confidence_level=0.95)
    return stock, var, cvar

# %%
from joblib import Parallel, delayed

# Parallelize the calculation for all stocks
results = Parallel(n_jobs=-1)(delayed(calculate_metrics_for_stock)(group) for name, group in grouped_data)

# Convert results to a DataFrame
risk_metrics_df = pd.DataFrame(results, columns=['Stock', 'VaR', 'CVaR'])
print(risk_metrics_df)
# Out:
#     Stock       VaR      CVaR
# 0       A -0.037924 -0.059862
# 1     AAL -0.058923 -0.094826
# 2     AAP -0.027961 -0.045678
# 3    AAPL -0.040973 -0.061643
# 4    ABBV -0.025420 -0.040784
# ..    ...       ...       ...
# 404   XYL -0.024667 -0.037997
# 405   YUM -0.027070 -0.042490
# 406   ZBH -0.025959 -0.041287
# 407  ZION -0.032370 -0.054554
# 408   ZTS -0.023941 -0.035957
#
# [409 rows x 3 columns]

# %%
import pandas as pd
import numpy as np

# Ensure 'Date' is in datetime format
data['Date'] = pd.to_datetime(data['Date'])

# Sort by Stock and Date
data = data.sort_values(by=['Stock', 'Date'])

# Drop any remaining missing values
data = data.dropna()

print(data.head())
# Out:
#         Date        Low       Open    Volume       High     Close  \
# 0 2000-02-01  47.389126  47.389126  0.000189  51.502148  0.000094
# 1 2000-02-02  51.189198  51.412731  0.000262  54.721031  0.000101
# 2 2000-02-03  52.798641  53.782188  0.000240  55.615166  0.000103
# 3 2000-02-04  53.648067  55.615166  0.000154  55.615166  0.000101
# 4 2000-02-07  54.542202  55.570457  0.000172  57.224606  0.000105
#
#    Adjusted Close Stock  Daily_Return     MA_10     MA_50       RSI  \
# 0       43.454834     A      0.072710  0.000092  0.000080  0.578431
# 1       46.821064     A      0.077465  0.000093  0.000081  0.712366
# 2       47.586102     A      0.016340  0.000095  0.000082  0.715426
# 3       46.668045     A     -0.019293  0.000096  0.000083  0.662371
# 4       48.657185     A      0.042623  0.000097  0.000084  0.664103
#
#    Volatility
# 0    0.000009
# 1    0.000012
# 2    0.000011
# 3    0.000011
# 4    0.000012

# %%
print(data.tail())
# Out:
#               Date         Low        Open    Volume        High     Close  \
# 3211093 2022-12-06  152.089996  154.220001  0.000265  155.500000  0.000284
# 3211094 2022-12-07  149.380005  152.960007  0.000329  153.789993  0.000279
# 3211095 2022-12-08  149.199997  150.529999  0.000306  154.350006  0.000285
# 3211096 2022-12-09  152.740005  153.940002  0.000441  156.330002  0.000284
# 3211097 2022-12-12  152.970001  154.070007  0.000041  154.470001  0.000285
#
#          Adjusted Close Stock  Daily_Return     MA_10     MA_50       RSI  \
# 3211093      153.050003   ZTS     -0.014678  0.000287  0.000292  0.554469
# 3211094      150.250000   ZTS     -0.018295  0.000287  0.000292  0.531867
# 3211095      153.679993   ZTS      0.022829  0.000288  0.000293  0.669926
# 3211096      153.389999   ZTS     -0.001887  0.000288  0.000293  0.638839
# 3211097      153.625000   ZTS      0.001532  0.000289  0.000293  0.618976
#
#          Volatility
# 3211093    0.000006
# 3211094    0.000006
# ...

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\aswin\anaconda3\envs\torch_env\python.exe

# %%
pip install gym
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
#      ---------------------------------------- 0.0/721.7 kB ? eta -:--:--
#      ------------------------------------- 721.7/721.7 kB 14.8 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for gym: filename=gym-0.26.2-py3-none-any.whl size=827628 sha256=0c3314946449ff3042f73e67c369bb5eee9cc5705e40b87205065e22a6b3d079
#   Stored in directory: C:\Users\aswin\AppData\Local\Temp\pip-ephem-wheel-cache-w44phzez\wheels\17\79\65\7afedc162d858b02708a3b8f7a6dd5b1000dcd5b0f894f7cc1
# Successfully built gym
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install stable_baselines3
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
#    ---------------------------------------- 0.0/958.1 kB ? eta -:--:--
#    --------------------------------------- 958.1/958.1 kB 43.5 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install shimmy>=2.0
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install gymnasium
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
def _calculate_var_cvar(self, returns, confidence_level=0.95):
    returns_sorted = returns.sort_values(ascending=True)
    var = returns_sorted.quantile(1 - confidence_level)
    cvar = returns_sorted[returns_sorted <= var].mean()
    return var, cvar

def _calculate_reward(self, action):
    # Example reward calculation incorporating risk metrics
    returns = self.df['Daily_Return'].iloc[:self.current_step + 1]
    var, cvar = self._calculate_var_cvar(returns)
    reward = self._calculate_profit() - var - cvar  # Example logic
    return reward

def _calculate_profit(self):
    # Define your profit calculation logic here
    return np.random.rand()  # Replace with actual profit calculation

# %%
import gymnasium as gym
import numpy as np
import pandas as pd
from stable_baselines3 import DDPG
from stable_baselines3.common.noise import NormalActionNoise
from stable_baselines3.common.env_util import DummyVecEnv

class TradingEnv(gym.Env):
    def __init__(self, df):
        super(TradingEnv, self).__init__()
        self.df = df
        self.numeric_columns = [col for col in df.columns if df[col].dtype in [np.float64, np.int64]]  # Exclude non-numeric columns
        self.action_space = gym.spaces.Box(low=-1, high=1, shape=(1,), dtype=np.float32)
        self.observation_space = gym.spaces.Box(low=0, high=1, shape=(len(self.numeric_columns),), dtype=np.float32)
        self.reset()

    def reset(self, **kwargs):
        self.current_step = 0
        self.current_data = self.df[self.numeric_columns].iloc[self.current_step]
        print("Reset observation:", self.current_data.values)  # Print observation for debugging
        return self.current_data.values  # Return only the observation

    def step(self, action):
        self.current_step += 1
        done = self.current_step >= len(self.df)
        reward = self._calculate_reward(action)
        self.current_data = self.df[self.numeric_columns].iloc[self.current_step] if not done else np.zeros(len(self.numeric_columns))
        info = {}  # Additional info (can be empty)
        print("Step observation:", self.current_data.values)  # Print observation for debugging
        return self.current_data.values, reward, done, info  # Return 4 values for compatibility

    def _calculate_reward(self, action):
        returns = self.df['Daily_Return'].iloc[:self.current_step + 1]
        var, cvar = self._calculate_var_cvar(returns)
        reward = self._calculate_profit() - var - cvar  # Example logic
        return reward

    def _calculate_var_cvar(self, returns, confidence_level=0.95):
        returns_sorted = returns.sort_values(ascending=True)
        var = returns_sorted.quantile(1 - confidence_level)
        cvar = returns_sorted[returns_sorted <= var].mean()
        return var, cvar

    def _calculate_profit(self):
        # Define your profit calculation logic here
        return np.random.rand()  # Replace with actual profit calculation
# Load preprocessed data
data = pd.read_csv("C:/Users/aswin/OneDrive/Desktop/Trading Bot/FinRL/preprocessed_data_with_features_sp500.csv")
env = DummyVecEnv([lambda: TradingEnv(data)])

# Define the DDPG agent
n_actions = env.action_space.shape[-1]
action_noise = NormalActionNoise(mean=np.zeros(n_actions), sigma=0.1 * np.ones(n_actions))

agent = DDPG(
    "MlpPolicy",
    env,
    action_noise=action_noise,
    verbose=1,
    device=device  # Specify the device as 'cuda' for GPU support
)

# Train the agent
agent.learn(total_timesteps=10000)

# Save the trained agent
agent.save("ddpg_trading_agent")

# Evaluate the agent
obs = env.reset()
for _ in range(1000):
    action, _states = agent.predict(obs, deterministic=True)
    obs, reward, done, truncated, info = env.step(action)
    if done:
        obs = env.reset()
# Out:
# Reset observation: [4.73891258e+01 4.73891258e+01 1.89215706e-04 5.15021477e+01
#  9.41927159e-05 4.34548340e+01 7.27100901e-02 9.23764010e-05
#  7.98670871e-05 5.78431414e-01 9.21139591e-06]
# Using cuda device
# Reset observation: [4.73891258e+01 4.73891258e+01 1.89215706e-04 5.15021477e+01
#  9.41927159e-05 4.34548340e+01 7.27100901e-02 9.23764010e-05
#  7.98670871e-05 5.78431414e-01 9.21139591e-06]
# Step observation: [5.11891975e+01 5.14127312e+01 2.62095277e-04 5.47210312e+01
#  1.01489338e-04 4.68210640e+01 7.74648072e-02 9.32528861e-05
#  8.08872019e-05 7.12365624e-01 1.17102399e-05]
# Step observation: [5.27986412e+01 5.37821884e+01 2.39773663e-04 5.56151657e+01
#  1.03147661e-04 4.75861015e+01 1.63398697e-02 9.45507581e-05
#  8.18402503e-05 7.15425539e-01 1.09898875e-05]
# Step observation: [ 5.36480675e+01  5.56151657e+01  1.54367616e-04  5.56151657e+01
#   1.01157669e-04  4.66680450e+01 -1.92926462e-02  9.55620865e-05
#   8.28638949e-05  6.62371061e-01  1.14863096e-05]
# ...
