# %% [markdown]
# **Data Collection & Preprocessing**
#
# I will start by fetching stock market data from Yahoo Finance, then clean and process it for training our risk management model.

# %% [markdown]
# **Install Required Libraries**

# %%
pip install finrl yfinance stable-baselines3 gym pandas numpy matplotlib seaborn
# Out:
# Collecting finrl
#   Downloading FinRL-0.3.7-py3-none-any.whl.metadata (909 bytes)
# Requirement already satisfied: yfinance in /usr/local/lib/python3.11/dist-packages (0.2.54)
# Collecting stable-baselines3
#   Downloading stable_baselines3-2.5.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: gym in /usr/local/lib/python3.11/dist-packages (0.25.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (1.26.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/dist-packages (0.13.2)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.11/dist-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.11/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from yfinance) (4.3.6)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.11/dist-packages (from yfinance) (2025.1)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.11/dist-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.11/dist-packages (from yfinance) (3.17.9)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.11/dist-packages (from yfinance) (4.13.3)
# Collecting gymnasium<1.1.0,>=0.29.1 (from stable-baselines3)
#   Downloading gymnasium-1.0.0-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3) (2.5.1+cu124)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from stable-baselines3) (3.1.1)
# Requirement already satisfied: gym_notices>=0.0.4 in /usr/local/lib/python3.11/dist-packages (from gym) (0.0.8)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.1.0,>=0.29.1->stable-baselines3) (0.0.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yfinance) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yfinance) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yfinance) (2025.1.31)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.17.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2024.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3.0,>=2.3->stable-baselines3) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<3.0,>=2.3->stable-baselines3) (3.0.2)
# Downloading FinRL-0.3.7-py3-none-any.whl (127 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.2/127.2 kB 4.0 MB/s eta 0:00:00
# Downloading stable_baselines3-2.5.0-py3-none-any.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 8.0 MB/s eta 0:00:00
# Downloading gymnasium-1.0.0-py3-none-any.whl (958 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 958.1/958.1 kB 12.1 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 22.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 23.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 15.0 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.0 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.6 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.8 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 56.2 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, gymnasium, finrl, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, stable-baselines3
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: gymnasium
#     Found existing installation: gymnasium 1.1.0
#     Uninstalling gymnasium-1.1.0:
#       Successfully uninstalled gymnasium-1.1.0
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed finrl-0.3.7 gymnasium-1.0.0 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 stable-baselines3-2.5.0

# %%
# !pip install stockstats
# Out:
# Collecting stockstats
#   Downloading stockstats-0.6.4-py2.py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: numpy>=1.16.6 in /usr/local/lib/python3.11/dist-packages (from stockstats) (1.26.4)
# Requirement already satisfied: pandas>=0.24.2 in /usr/local/lib/python3.11/dist-packages (from stockstats) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24.2->stockstats) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24.2->stockstats) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24.2->stockstats) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=0.24.2->stockstats) (1.17.0)
# Downloading stockstats-0.6.4-py2.py3-none-any.whl (31 kB)
# Installing collected packages: stockstats
# Successfully installed stockstats-0.6.4

# %%
# !pip install finrl --upgrade
# Out:
# Requirement already satisfied: finrl in /usr/local/lib/python3.11/dist-packages (0.3.7)

# %%
# !pip install alpaca-trade-api
# Out:
# Collecting alpaca-trade-api
#   Downloading alpaca_trade_api-3.2.0-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: pandas>=0.18.1 in /usr/local/lib/python3.11/dist-packages (from alpaca-trade-api) (2.2.2)
# Requirement already satisfied: numpy>=1.11.1 in /usr/local/lib/python3.11/dist-packages (from alpaca-trade-api) (1.26.4)
# Requirement already satisfied: requests<3,>2 in /usr/local/lib/python3.11/dist-packages (from alpaca-trade-api) (2.32.3)
# Collecting urllib3<2,>1.24 (from alpaca-trade-api)
#   Downloading urllib3-1.26.20-py2.py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: websocket-client<2,>=0.56.0 in /usr/local/lib/python3.11/dist-packages (from alpaca-trade-api) (1.8.0)
# Collecting websockets<11,>=9.0 (from alpaca-trade-api)
#   Downloading websockets-10.4-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.4 kB)
# Collecting msgpack==1.0.3 (from alpaca-trade-api)
#   Downloading msgpack-1.0.3.tar.gz (123 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.8/123.8 kB 9.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: aiohttp<4,>=3.8.3 in /usr/local/lib/python3.11/dist-packages (from alpaca-trade-api) (3.11.13)
# Collecting PyYAML==6.0.1 (from alpaca-trade-api)
#   Downloading PyYAML-6.0.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting deprecation==2.1.0 (from alpaca-trade-api)
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from deprecation==2.1.0->alpaca-trade-api) (24.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api) (1.18.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.18.1->alpaca-trade-api) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.18.1->alpaca-trade-api) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.18.1->alpaca-trade-api) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>2->alpaca-trade-api) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>2->alpaca-trade-api) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>2->alpaca-trade-api) (2025.1.31)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=0.18.1->alpaca-trade-api) (1.17.0)
# Downloading alpaca_trade_api-3.2.0-py3-none-any.whl (34 kB)
# Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Downloading PyYAML-6.0.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (757 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 757.7/757.7 kB 23.5 MB/s eta 0:00:00
# Downloading urllib3-1.26.20-py2.py3-none-any.whl (144 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.2/144.2 kB 7.6 MB/s eta 0:00:00
# Downloading websockets-10.4-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (107 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.4/107.4 kB 6.1 MB/s eta 0:00:00
# Building wheels for collected packages: msgpack
#   Building wheel for msgpack (setup.py) ... done
#   Created wheel for msgpack: filename=msgpack-1.0.3-cp311-cp311-linux_x86_64.whl size=15688 sha256=885bee1414ee13f35146db93d560d651f6a2bfd8510395bc94cd62d5d1292585
#   Stored in directory: /root/.cache/pip/wheels/f6/35/da/ed9b26b510235e00e3a3c3bab7bad97b59214729662255ab3d
# Successfully built msgpack
# Installing collected packages: msgpack, websockets, urllib3, PyYAML, deprecation, alpaca-trade-api
#   Attempting uninstall: msgpack
#     Found existing installation: msgpack 1.1.0
#     Uninstalling msgpack-1.1.0:
#       Successfully uninstalled msgpack-1.1.0
#   Attempting uninstall: websockets
#     Found existing installation: websockets 14.2
#     Uninstalling websockets-14.2:
#       Successfully uninstalled websockets-14.2
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.3.0
#     Uninstalling urllib3-2.3.0:
#       Successfully uninstalled urllib3-2.3.0
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 6.0.2
#     Uninstalling PyYAML-6.0.2:
#       Successfully uninstalled PyYAML-6.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-genai 0.8.0 requires websockets<15.0dev,>=13.0, but you have websockets 10.4 which is incompatible.
# Successfully installed PyYAML-6.0.1 alpaca-trade-api-3.2.0 deprecation-2.1.0 msgpack-1.0.3 urllib3-1.26.20 websockets-10.4

# %%
# !pip install git+https://github.com/AI4Finance-LLC/FinRL-Library.git
# Out:
# Collecting git+https://github.com/AI4Finance-LLC/FinRL-Library.git
#   Cloning https://github.com/AI4Finance-LLC/FinRL-Library.git to /tmp/pip-req-build-2w8go3m0
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-LLC/FinRL-Library.git /tmp/pip-req-build-2w8go3m0
#   Resolved https://github.com/AI4Finance-LLC/FinRL-Library.git to commit 8cf3cacc6f570d26b430e403ea522c8fe9e6876a
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git (from finrl==0.3.6)
#   Cloning https://github.com/AI4Finance-Foundation/ElegantRL.git to /tmp/pip-install-4cjl7cf6/elegantrl_184bedcb951f4489814efa66d7477d6e
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-Foundation/ElegantRL.git /tmp/pip-install-4cjl7cf6/elegantrl_184bedcb951f4489814efa66d7477d6e
#   Resolved https://github.com/AI4Finance-Foundation/ElegantRL.git to commit 3bdc958c8e624b61a9e661832b01fef816924f61
#   Preparing metadata (setup.py) ... done
# Collecting alpaca-py<0.38,>=0.37 (from finrl==0.3.6)
#   Downloading alpaca_py-0.37.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: alpaca-trade-api<4,>=3 in /usr/local/lib/python3.11/dist-packages (from finrl==0.3.6) (3.2.0)
# Collecting ccxt<4,>=3 (from finrl==0.3.6)
#   Downloading ccxt-3.1.60-py2.py3-none-any.whl.metadata (108 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.7/108.7 kB 7.1 MB/s eta 0:00:00
# Collecting exchange-calendars<5,>=4 (from finrl==0.3.6)
#   Downloading exchange_calendars-4.9-py3-none-any.whl.metadata (37 kB)
# Collecting jqdatasdk<2,>=1 (from finrl==0.3.6)
#   Downloading jqdatasdk-1.9.7-py3-none-any.whl.metadata (5.8 kB)
# Collecting pyfolio<0.10,>=0.9 (from finrl==0.3.6)
#   Downloading pyfolio-0.9.2.tar.gz (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.1/91.1 kB 8.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pyportfolioopt<2,>=1 (from finrl==0.3.6)
#   Downloading pyportfolioopt-1.5.6-py3-none-any.whl.metadata (22 kB)
# Collecting ray<3,>=2 (from ray[default,tune]<3,>=2->finrl==0.3.6)
#   Downloading ray-2.43.0-cp311-cp311-manylinux2014_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: scikit-learn<2,>=1 in /usr/local/lib/python3.11/dist-packages (from finrl==0.3.6) (1.6.1)
# Collecting selenium<5,>=4 (from finrl==0.3.6)
#   Downloading selenium-4.29.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: stable-baselines3>=2.0.0a5 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.5.0)
# Collecting stockstats<0.6,>=0.5 (from finrl==0.3.6)
#   Downloading stockstats-0.5.4-py2.py3-none-any.whl.metadata (26 kB)
# Collecting webdriver-manager<5,>=4 (from finrl==0.3.6)
#   Downloading webdriver_manager-4.0.2-py2.py3-none-any.whl.metadata (12 kB)
# Collecting wrds<4,>=3 (from finrl==0.3.6)
#   Downloading wrds-3.3.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: yfinance<0.3,>=0.2 in /usr/local/lib/python3.11/dist-packages (from finrl==0.3.6) (0.2.54)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.3 in /usr/local/lib/python3.11/dist-packages (from alpaca-py<0.38,>=0.37->finrl==0.3.6) (1.0.3)
# Requirement already satisfied: pandas>=1.5.3 in /usr/local/lib/python3.11/dist-packages (from alpaca-py<0.38,>=0.37->finrl==0.3.6) (2.2.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.3 in /usr/local/lib/python3.11/dist-packages (from alpaca-py<0.38,>=0.37->finrl==0.3.6) (2.10.6)
# Requirement already satisfied: requests<3.0.0,>=2.30.0 in /usr/local/lib/python3.11/dist-packages (from alpaca-py<0.38,>=0.37->finrl==0.3.6) (2.32.3)
# Collecting sseclient-py<2.0.0,>=1.7.2 (from alpaca-py<0.38,>=0.37->finrl==0.3.6)
#   Downloading sseclient_py-1.8.0-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.11/dist-packages (from alpaca-py<0.38,>=0.37->finrl==0.3.6) (10.4)
# Requirement already satisfied: numpy>=1.11.1 in /usr/local/lib/python3.11/dist-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (1.26.4)
# Requirement already satisfied: urllib3<2,>1.24 in /usr/local/lib/python3.11/dist-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (1.26.20)
# Requirement already satisfied: websocket-client<2,>=0.56.0 in /usr/local/lib/python3.11/dist-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (1.8.0)
# Requirement already satisfied: aiohttp<4,>=3.8.3 in /usr/local/lib/python3.11/dist-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (3.11.13)
# Requirement already satisfied: PyYAML==6.0.1 in /usr/local/lib/python3.11/dist-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (6.0.1)
# Requirement already satisfied: deprecation==2.1.0 in /usr/local/lib/python3.11/dist-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (2.1.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from deprecation==2.1.0->alpaca-trade-api<4,>=3->finrl==0.3.6) (24.2)
# Requirement already satisfied: setuptools>=60.9.0 in /usr/local/lib/python3.11/dist-packages (from ccxt<4,>=3->finrl==0.3.6) (75.1.0)
# Requirement already satisfied: certifi>=2018.1.18 in /usr/local/lib/python3.11/dist-packages (from ccxt<4,>=3->finrl==0.3.6) (2025.1.31)
# Requirement already satisfied: cryptography>=2.6.1 in /usr/local/lib/python3.11/dist-packages (from ccxt<4,>=3->finrl==0.3.6) (43.0.3)
# Collecting aiodns>=1.1.1 (from ccxt<4,>=3->finrl==0.3.6)
#   Downloading aiodns-3.2.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: yarl>=1.7.2 in /usr/local/lib/python3.11/dist-packages (from ccxt<4,>=3->finrl==0.3.6) (1.18.3)
# Collecting pyluach (from exchange-calendars<5,>=4->finrl==0.3.6)
#   Downloading pyluach-2.2.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: toolz in /usr/local/lib/python3.11/dist-packages (from exchange-calendars<5,>=4->finrl==0.3.6) (0.12.1)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.11/dist-packages (from exchange-calendars<5,>=4->finrl==0.3.6) (2025.1)
# Collecting korean_lunar_calendar (from exchange-calendars<5,>=4->finrl==0.3.6)
#   Downloading korean_lunar_calendar-0.3.1-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from jqdatasdk<2,>=1->finrl==0.3.6) (1.17.0)
# Requirement already satisfied: SQLAlchemy>=1.2.8 in /usr/local/lib/python3.11/dist-packages (from jqdatasdk<2,>=1->finrl==0.3.6) (2.0.38)
# Collecting pymysql>=0.7.6 (from jqdatasdk<2,>=1->finrl==0.3.6)
#   Downloading PyMySQL-1.1.1-py3-none-any.whl.metadata (4.4 kB)
# Collecting thriftpy2!=0.5.1,>=0.3.9 (from jqdatasdk<2,>=1->finrl==0.3.6)
#   Downloading thriftpy2-0.5.2.tar.gz (782 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 782.3/782.3 kB 45.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: ipython>=3.2.3 in /usr/local/lib/python3.11/dist-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (7.34.0)
# Requirement already satisfied: matplotlib>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (3.10.0)
# Requirement already satisfied: pytz>=2014.10 in /usr/local/lib/python3.11/dist-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (2025.1)
# Requirement already satisfied: scipy>=0.14.0 in /usr/local/lib/python3.11/dist-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (1.13.1)
# Requirement already satisfied: seaborn>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (0.13.2)
# Collecting empyrical>=0.5.0 (from pyfolio<0.10,>=0.9->finrl==0.3.6)
#   Downloading empyrical-0.5.5.tar.gz (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 3.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: cvxpy>=1.1.19 in /usr/local/lib/python3.11/dist-packages (from pyportfolioopt<2,>=1->finrl==0.3.6) (1.6.2)
# Collecting ecos<3.0.0,>=2.0.14 (from pyportfolioopt<2,>=1->finrl==0.3.6)
#   Downloading ecos-2.0.14-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.0 kB)
# Requirement already satisfied: plotly<6.0.0,>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from pyportfolioopt<2,>=1->finrl==0.3.6) (5.24.1)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.11/dist-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.6) (8.1.8)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.6) (3.17.0)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.11/dist-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.6) (4.23.0)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /usr/local/lib/python3.11/dist-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.6) (4.25.6)
# Requirement already satisfied: aiosignal in /usr/local/lib/python3.11/dist-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.6) (1.3.2)
# Requirement already satisfied: frozenlist in /usr/local/lib/python3.11/dist-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.6) (1.5.0)
# Collecting aiohttp_cors (from ray[default,tune]<3,>=2->finrl==0.3.6)
#   Downloading aiohttp_cors-0.7.0-py3-none-any.whl.metadata (20 kB)
# Collecting colorful (from ray[default,tune]<3,>=2->finrl==0.3.6)
#   Downloading colorful-0.5.6-py2.py3-none-any.whl.metadata (16 kB)
# Collecting py-spy>=0.2.0 (from ray[default,tune]<3,>=2->finrl==0.3.6)
#   Downloading py_spy-0.4.0-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (16 kB)
# Requirement already satisfied: grpcio>=1.42.0 in /usr/local/lib/python3.11/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (1.70.0)
# Collecting opencensus (from ray[default,tune]<3,>=2->finrl==0.3.6)
#   Downloading opencensus-0.11.4-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: prometheus_client>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (0.21.1)
# Requirement already satisfied: smart_open in /usr/local/lib/python3.11/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (7.1.0)
# Collecting virtualenv!=20.21.1,>=20.0.24 (from ray[default,tune]<3,>=2->finrl==0.3.6)
#   Downloading virtualenv-20.29.2-py3-none-any.whl.metadata (4.5 kB)
# Collecting tensorboardX>=1.9 (from ray[default,tune]<3,>=2->finrl==0.3.6)
#   Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: pyarrow>=9.0.0 in /usr/local/lib/python3.11/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (18.1.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (2024.10.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<2,>=1->finrl==0.3.6) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<2,>=1->finrl==0.3.6) (3.5.0)
# Collecting trio~=0.17 (from selenium<5,>=4->finrl==0.3.6)
#   Downloading trio-0.29.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting trio-websocket~=0.9 (from selenium<5,>=4->finrl==0.3.6)
#   Downloading trio_websocket-0.12.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: typing_extensions~=4.9 in /usr/local/lib/python3.11/dist-packages (from selenium<5,>=4->finrl==0.3.6) (4.12.2)
# Requirement already satisfied: gymnasium<1.1.0,>=0.29.1 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (1.0.0)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.5.1+cu124)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.1.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (4.11.0.86)
# Requirement already satisfied: pygame in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.6.1)
# Requirement already satisfied: tensorboard>=2.9.1 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.18.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (5.9.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (4.67.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (13.9.4)
# Requirement already satisfied: ale-py>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.10.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (11.1.0)
# Collecting python-dotenv (from webdriver-manager<5,>=4->finrl==0.3.6)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting psycopg2-binary<2.10,>=2.9 (from wrds<4,>=3->finrl==0.3.6)
#   Downloading psycopg2_binary-2.9.10-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.11/dist-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (4.3.6)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.11/dist-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.11/dist-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (3.17.9)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.11/dist-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (4.13.3)
# Collecting th (from elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git->finrl==0.3.6)
#   Downloading th-0.4.1-py3-none-any.whl.metadata (3.4 kB)
# Collecting pycares>=4.0.0 (from aiodns>=1.1.1->ccxt<4,>=3->finrl==0.3.6)
#   Downloading pycares-4.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.6) (2.4.6)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.6) (25.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.6) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.6) (0.3.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.11.1->yfinance<0.3,>=0.2->finrl==0.3.6) (2.6)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography>=2.6.1->ccxt<4,>=3->finrl==0.3.6) (1.17.1)
# Requirement already satisfied: osqp>=0.6.2 in /usr/local/lib/python3.11/dist-packages (from cvxpy>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.6) (0.6.7.post3)
# Requirement already satisfied: clarabel>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from cvxpy>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.6) (0.10.0)
# Requirement already satisfied: scs>=3.2.4.post1 in /usr/local/lib/python3.11/dist-packages (from cvxpy>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.6) (3.2.7.post2)
# Requirement already satisfied: pandas-datareader>=0.2 in /usr/local/lib/python3.11/dist-packages (from empyrical>=0.5.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.10.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.1.0,>=0.29.1->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.0.4)
# Collecting jedi>=0.16 (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.11/dist-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (3.0.50)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (4.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (2.8.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly<6.0.0,>=5.0.0->pyportfolioopt<2,>=1->finrl==0.3.6) (9.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.0.3->alpaca-py<0.38,>=0.37->finrl==0.3.6) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.0.3->alpaca-py<0.38,>=0.37->finrl==0.3.6) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.30.0->alpaca-py<0.38,>=0.37->finrl==0.3.6) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.30.0->alpaca-py<0.38,>=0.37->finrl==0.3.6) (3.10)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy>=1.2.8->jqdatasdk<2,>=1->finrl==0.3.6) (3.1.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (1.4.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.1.3)
# Requirement already satisfied: Cython>=3.0.10 in /usr/local/lib/python3.11/dist-packages (from thriftpy2!=0.5.1,>=0.3.9->jqdatasdk<2,>=1->finrl==0.3.6) (3.0.12)
# Requirement already satisfied: ply<4.0,>=3.4 in /usr/local/lib/python3.11/dist-packages (from thriftpy2!=0.5.1,>=0.3.9->jqdatasdk<2,>=1->finrl==0.3.6) (3.11)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.1.5)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (1.3.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.11/dist-packages (from trio~=0.17->selenium<5,>=4->finrl==0.3.6) (2.4.0)
# Collecting outcome (from trio~=0.17->selenium<5,>=4->finrl==0.3.6)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: sniffio>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from trio~=0.17->selenium<5,>=4->finrl==0.3.6) (1.3.1)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium<5,>=4->finrl==0.3.6)
#   Downloading wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from urllib3[socks]<3,>=1.26->selenium<5,>=4->finrl==0.3.6) (1.7.1)
# Collecting distlib<1,>=0.3.7 (from virtualenv!=20.21.1,>=20.0.24->ray[default,tune]<3,>=2->finrl==0.3.6)
#   Downloading distlib-0.3.9-py2.py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema->ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.6) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema->ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.6) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema->ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.6) (0.23.1)
# Collecting opencensus-context>=0.1.3 (from opencensus->ray[default,tune]<3,>=2->finrl==0.3.6)
#   Downloading opencensus_context-0.1.3-py2.py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from opencensus->ray[default,tune]<3,>=2->finrl==0.3.6) (2.24.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.0.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart_open->ray[default,tune]<3,>=2->finrl==0.3.6) (1.17.2)
# Collecting niltype<2.0,>=0.3 (from th->elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git->finrl==0.3.6)
#   Downloading niltype-1.0.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography>=2.6.1->ccxt<4,>=3->finrl==0.3.6) (2.22)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.6) (1.68.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.6) (1.26.0)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.6) (2.27.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.8.4)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.1.2)
# Requirement already satisfied: qdldl in /usr/local/lib/python3.11/dist-packages (from osqp>=0.6.2->cvxpy>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.6) (0.1.7.post5)
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/dist-packages (from pandas-datareader>=0.2->empyrical>=0.5.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (5.3.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.2.13)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.0.2)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium<5,>=4->finrl==0.3.6) (0.14.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.6) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.6) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.6) (4.9)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.6) (0.6.1)
# Downloading alpaca_py-0.37.0-py3-none-any.whl (121 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.5/121.5 kB 10.1 MB/s eta 0:00:00
# Downloading ccxt-3.1.60-py2.py3-none-any.whl (4.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 70.8 MB/s eta 0:00:00
# Downloading exchange_calendars-4.9-py3-none-any.whl (198 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 198.0/198.0 kB 13.9 MB/s eta 0:00:00
# Downloading jqdatasdk-1.9.7-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 6.6 MB/s eta 0:00:00
# Downloading pyportfolioopt-1.5.6-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 5.6 MB/s eta 0:00:00
# Downloading ray-2.43.0-cp311-cp311-manylinux2014_x86_64.whl (67.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.7/67.7 MB 12.2 MB/s eta 0:00:00
# Downloading selenium-4.29.0-py3-none-any.whl (9.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 76.7 MB/s eta 0:00:00
# Downloading stockstats-0.5.4-py2.py3-none-any.whl (21 kB)
# Downloading webdriver_manager-4.0.2-py2.py3-none-any.whl (27 kB)
# Downloading wrds-3.3.0-py3-none-any.whl (13 kB)
# Downloading aiodns-3.2.0-py3-none-any.whl (5.7 kB)
# Downloading ecos-2.0.14-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (220 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.1/220.1 kB 17.9 MB/s eta 0:00:00
# Downloading psycopg2_binary-2.9.10-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 78.5 MB/s eta 0:00:00
# Downloading py_spy-0.4.0-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 86.1 MB/s eta 0:00:00
# Downloading PyMySQL-1.1.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 3.8 MB/s eta 0:00:00
# Downloading sseclient_py-1.8.0-py2.py3-none-any.whl (8.8 kB)
# Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 8.4 MB/s eta 0:00:00
# Downloading trio-0.29.0-py3-none-any.whl (492 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 492.9/492.9 kB 33.7 MB/s eta 0:00:00
# Downloading trio_websocket-0.12.2-py3-none-any.whl (21 kB)
# Downloading virtualenv-20.29.2-py3-none-any.whl (4.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 90.8 MB/s eta 0:00:00
# Downloading aiohttp_cors-0.7.0-py3-none-any.whl (27 kB)
# Downloading colorful-0.5.6-py2.py3-none-any.whl (201 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.4/201.4 kB 18.1 MB/s eta 0:00:00
# Downloading korean_lunar_calendar-0.3.1-py3-none-any.whl (9.0 kB)
# Downloading opencensus-0.11.4-py2.py3-none-any.whl (128 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 kB 11.2 MB/s eta 0:00:00
# Downloading pyluach-2.2.0-py3-none-any.whl (25 kB)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading th-0.4.1-py3-none-any.whl (12 kB)
# Downloading distlib-0.3.9-py2.py3-none-any.whl (468 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 33.2 MB/s eta 0:00:00
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 65.3 MB/s eta 0:00:00
# Downloading niltype-1.0.2-py3-none-any.whl (5.3 kB)
# Downloading opencensus_context-0.1.3-py2.py3-none-any.whl (5.1 kB)
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Downloading pycares-4.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (288 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.6/288.6 kB 22.4 MB/s eta 0:00:00
# Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Building wheels for collected packages: finrl, pyfolio, elegantrl, empyrical, thriftpy2
#   Building wheel for finrl (pyproject.toml) ... done
#   Created wheel for finrl: filename=finrl-0.3.6-py3-none-any.whl size=4695553 sha256=48f934741137e20498422d55f7386f282c69013d96378926c0da3a1259665c45
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ocjqcc6u/wheels/8b/b9/dd/869abb6fb088e669a786de7f16c0350c604af99e6ee25d43f1
#   Building wheel for pyfolio (setup.py) ... done
#   Created wheel for pyfolio: filename=pyfolio-0.9.2-py3-none-any.whl size=88656 sha256=88c00b7792a65c734893ccfe0ceccc6aa74b4837ff28def21e67c2c1fd1ccd1d
#   Stored in directory: /root/.cache/pip/wheels/f9/af/9e/7c343b822164a3147a3d395a1bcd05041c520a3bc6398fe88e
#   Building wheel for elegantrl (setup.py) ... done
#   Created wheel for elegantrl: filename=ElegantRL-0.3.10-py3-none-any.whl size=271971 sha256=146f67b4783c965de11f5ebba31c0fdd05e3d53ee235e7c90e26c9dc27fc7003
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ocjqcc6u/wheels/9a/77/4d/6284111037b2dd64af9ef18d4d600d9c185cc2f6f09704e896
#   Building wheel for empyrical (setup.py) ... done
#   Created wheel for empyrical: filename=empyrical-0.5.5-py3-none-any.whl size=39753 sha256=69025f941323884782d3cc2b6bbe02fc808e9d1de3597fe3be57074f53cff29a
#   Stored in directory: /root/.cache/pip/wheels/ac/1d/58/a7ae5ef5c8de7c4b769f24c2584f4706564921f031b16b9cb6
#   Building wheel for thriftpy2 (pyproject.toml) ... done
#   Created wheel for thriftpy2: filename=thriftpy2-0.5.2-cp311-cp311-linux_x86_64.whl size=1824783 sha256=cce95689d6dba59a16b3ac9f8370b87f80734612c3097b2ee7c2a49d9d41864c
#   Stored in directory: /root/.cache/pip/wheels/17/32/fa/51ae0364792430fb80858f4705c9e0cba3d6900f591f0c4495
# Successfully built finrl pyfolio elegantrl empyrical thriftpy2
# Installing collected packages: sseclient-py, py-spy, opencensus-context, korean_lunar_calendar, distlib, colorful, wsproto, virtualenv, thriftpy2, tensorboardX, python-dotenv, pymysql, pyluach, psycopg2-binary, outcome, niltype, jedi, webdriver-manager, trio, th, pycares, ecos, wrds, trio-websocket, stockstats, jqdatasdk, exchange-calendars, elegantrl, alpaca-py, aiohttp_cors, aiodns, selenium, ray, opencensus, empyrical, ccxt, pyportfolioopt, pyfolio, finrl
#   Attempting uninstall: stockstats
#     Found existing installation: stockstats 0.6.4
#     Uninstalling stockstats-0.6.4:
#       Successfully uninstalled stockstats-0.6.4
#   Attempting uninstall: finrl
#     Found existing installation: FinRL 0.3.7
#     Uninstalling FinRL-0.3.7:
#       Successfully uninstalled FinRL-0.3.7
# Successfully installed aiodns-3.2.0 aiohttp_cors-0.7.0 alpaca-py-0.37.0 ccxt-3.1.60 colorful-0.5.6 distlib-0.3.9 ecos-2.0.14 elegantrl-0.3.10 empyrical-0.5.5 exchange-calendars-4.9 finrl-0.3.6 jedi-0.19.2 jqdatasdk-1.9.7 korean_lunar_calendar-0.3.1 niltype-1.0.2 opencensus-0.11.4 opencensus-context-0.1.3 outcome-1.3.0.post0 psycopg2-binary-2.9.10 py-spy-0.4.0 pycares-4.5.0 pyfolio-0.9.2 pyluach-2.2.0 pymysql-1.1.1 pyportfolioopt-1.5.6 python-dotenv-1.0.1 ray-2.43.0 selenium-4.29.0 sseclient-py-1.8.0 stockstats-0.5.4 tensorboardX-2.6.2.2 th-0.4.1 thriftpy2-0.5.2 trio-0.29.0 trio-websocket-0.12.2 virtualenv-20.29.2 webdriver-manager-4.0.2 wrds-3.3.0 wsproto-1.2.0

# %%
# !pip install exchange-calendars
# Out:
# Requirement already satisfied: exchange-calendars in /usr/local/lib/python3.11/dist-packages (4.9)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from exchange-calendars) (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from exchange-calendars) (2.2.2)
# Requirement already satisfied: pyluach in /usr/local/lib/python3.11/dist-packages (from exchange-calendars) (2.2.0)
# Requirement already satisfied: toolz in /usr/local/lib/python3.11/dist-packages (from exchange-calendars) (0.12.1)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.11/dist-packages (from exchange-calendars) (2025.1)
# Requirement already satisfied: korean_lunar_calendar in /usr/local/lib/python3.11/dist-packages (from exchange-calendars) (0.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->exchange-calendars) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->exchange-calendars) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->exchange-calendars) (1.17.0)

# %%
# !pip install wrds
# Out:
# Requirement already satisfied: wrds in /usr/local/lib/python3.11/dist-packages (3.3.0)
# Requirement already satisfied: packaging<=24.2 in /usr/local/lib/python3.11/dist-packages (from wrds) (24.2)
# Requirement already satisfied: pandas<2.3,>=2.2 in /usr/local/lib/python3.11/dist-packages (from wrds) (2.2.2)
# Requirement already satisfied: psycopg2-binary<2.10,>=2.9 in /usr/local/lib/python3.11/dist-packages (from wrds) (2.9.10)
# Requirement already satisfied: sqlalchemy<2.1,>=2 in /usr/local/lib/python3.11/dist-packages (from wrds) (2.0.38)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas<2.3,>=2.2->wrds) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas<2.3,>=2.2->wrds) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<2.3,>=2.2->wrds) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<2.3,>=2.2->wrds) (2025.1)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy<2.1,>=2->wrds) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy<2.1,>=2->wrds) (4.12.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas<2.3,>=2.2->wrds) (1.17.0)

# %%
# !pip install finrl
# Out:
# Requirement already satisfied: finrl in /usr/local/lib/python3.11/dist-packages (0.3.6)
# Collecting elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git (from finrl)
#   Cloning https://github.com/AI4Finance-Foundation/ElegantRL.git to /tmp/pip-install-sor7e_mv/elegantrl_2fada21a713f4f3fba89a9f4ba5ad560
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-Foundation/ElegantRL.git /tmp/pip-install-sor7e_mv/elegantrl_2fada21a713f4f3fba89a9f4ba5ad560
#   Resolved https://github.com/AI4Finance-Foundation/ElegantRL.git to commit 3bdc958c8e624b61a9e661832b01fef816924f61
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: alpaca-py<0.38,>=0.37 in /usr/local/lib/python3.11/dist-packages (from finrl) (0.37.0)
# Requirement already satisfied: alpaca-trade-api<4,>=3 in /usr/local/lib/python3.11/dist-packages (from finrl) (3.2.0)
# Requirement already satisfied: ccxt<4,>=3 in /usr/local/lib/python3.11/dist-packages (from finrl) (3.1.60)
# Requirement already satisfied: exchange-calendars<5,>=4 in /usr/local/lib/python3.11/dist-packages (from finrl) (4.9)
# Requirement already satisfied: jqdatasdk<2,>=1 in /usr/local/lib/python3.11/dist-packages (from finrl) (1.9.7)
# Requirement already satisfied: pyfolio<0.10,>=0.9 in /usr/local/lib/python3.11/dist-packages (from finrl) (0.9.2)
# Requirement already satisfied: pyportfolioopt<2,>=1 in /usr/local/lib/python3.11/dist-packages (from finrl) (1.5.6)
# Requirement already satisfied: ray<3,>=2 in /usr/local/lib/python3.11/dist-packages (from ray[default,tune]<3,>=2->finrl) (2.43.0)
# Requirement already satisfied: scikit-learn<2,>=1 in /usr/local/lib/python3.11/dist-packages (from finrl) (1.6.1)
# Requirement already satisfied: selenium<5,>=4 in /usr/local/lib/python3.11/dist-packages (from finrl) (4.29.0)
# Requirement already satisfied: stable-baselines3>=2.0.0a5 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl) (2.5.0)
# Requirement already satisfied: stockstats<0.6,>=0.5 in /usr/local/lib/python3.11/dist-packages (from finrl) (0.5.4)
# Requirement already satisfied: webdriver-manager<5,>=4 in /usr/local/lib/python3.11/dist-packages (from finrl) (4.0.2)
# Requirement already satisfied: wrds<4,>=3 in /usr/local/lib/python3.11/dist-packages (from finrl) (3.3.0)
# Requirement already satisfied: yfinance<0.3,>=0.2 in /usr/local/lib/python3.11/dist-packages (from finrl) (0.2.54)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.3 in /usr/local/lib/python3.11/dist-packages (from alpaca-py<0.38,>=0.37->finrl) (1.0.3)
# Requirement already satisfied: pandas>=1.5.3 in /usr/local/lib/python3.11/dist-packages (from alpaca-py<0.38,>=0.37->finrl) (2.2.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.3 in /usr/local/lib/python3.11/dist-packages (from alpaca-py<0.38,>=0.37->finrl) (2.10.6)
# Requirement already satisfied: requests<3.0.0,>=2.30.0 in /usr/local/lib/python3.11/dist-packages (from alpaca-py<0.38,>=0.37->finrl) (2.32.3)
# Requirement already satisfied: sseclient-py<2.0.0,>=1.7.2 in /usr/local/lib/python3.11/dist-packages (from alpaca-py<0.38,>=0.37->finrl) (1.8.0)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.11/dist-packages (from alpaca-py<0.38,>=0.37->finrl) (10.4)
# Requirement already satisfied: numpy>=1.11.1 in /usr/local/lib/python3.11/dist-packages (from alpaca-trade-api<4,>=3->finrl) (1.26.4)
# Requirement already satisfied: urllib3<2,>1.24 in /usr/local/lib/python3.11/dist-packages (from alpaca-trade-api<4,>=3->finrl) (1.26.20)
# Requirement already satisfied: websocket-client<2,>=0.56.0 in /usr/local/lib/python3.11/dist-packages (from alpaca-trade-api<4,>=3->finrl) (1.8.0)
# Requirement already satisfied: aiohttp<4,>=3.8.3 in /usr/local/lib/python3.11/dist-packages (from alpaca-trade-api<4,>=3->finrl) (3.11.13)
# Requirement already satisfied: PyYAML==6.0.1 in /usr/local/lib/python3.11/dist-packages (from alpaca-trade-api<4,>=3->finrl) (6.0.1)
# Requirement already satisfied: deprecation==2.1.0 in /usr/local/lib/python3.11/dist-packages (from alpaca-trade-api<4,>=3->finrl) (2.1.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from deprecation==2.1.0->alpaca-trade-api<4,>=3->finrl) (24.2)
# Requirement already satisfied: setuptools>=60.9.0 in /usr/local/lib/python3.11/dist-packages (from ccxt<4,>=3->finrl) (75.1.0)
# Requirement already satisfied: certifi>=2018.1.18 in /usr/local/lib/python3.11/dist-packages (from ccxt<4,>=3->finrl) (2025.1.31)
# Requirement already satisfied: cryptography>=2.6.1 in /usr/local/lib/python3.11/dist-packages (from ccxt<4,>=3->finrl) (43.0.3)
# Requirement already satisfied: aiodns>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from ccxt<4,>=3->finrl) (3.2.0)
# Requirement already satisfied: yarl>=1.7.2 in /usr/local/lib/python3.11/dist-packages (from ccxt<4,>=3->finrl) (1.18.3)
# Requirement already satisfied: pyluach in /usr/local/lib/python3.11/dist-packages (from exchange-calendars<5,>=4->finrl) (2.2.0)
# Requirement already satisfied: toolz in /usr/local/lib/python3.11/dist-packages (from exchange-calendars<5,>=4->finrl) (0.12.1)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.11/dist-packages (from exchange-calendars<5,>=4->finrl) (2025.1)
# Requirement already satisfied: korean_lunar_calendar in /usr/local/lib/python3.11/dist-packages (from exchange-calendars<5,>=4->finrl) (0.3.1)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from jqdatasdk<2,>=1->finrl) (1.17.0)
# Requirement already satisfied: SQLAlchemy>=1.2.8 in /usr/local/lib/python3.11/dist-packages (from jqdatasdk<2,>=1->finrl) (2.0.38)
# Requirement already satisfied: pymysql>=0.7.6 in /usr/local/lib/python3.11/dist-packages (from jqdatasdk<2,>=1->finrl) (1.1.1)
# Requirement already satisfied: thriftpy2!=0.5.1,>=0.3.9 in /usr/local/lib/python3.11/dist-packages (from jqdatasdk<2,>=1->finrl) (0.5.2)
# Requirement already satisfied: ipython>=3.2.3 in /usr/local/lib/python3.11/dist-packages (from pyfolio<0.10,>=0.9->finrl) (7.34.0)
# Requirement already satisfied: matplotlib>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from pyfolio<0.10,>=0.9->finrl) (3.10.0)
# Requirement already satisfied: pytz>=2014.10 in /usr/local/lib/python3.11/dist-packages (from pyfolio<0.10,>=0.9->finrl) (2025.1)
# Requirement already satisfied: scipy>=0.14.0 in /usr/local/lib/python3.11/dist-packages (from pyfolio<0.10,>=0.9->finrl) (1.13.1)
# Requirement already satisfied: seaborn>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from pyfolio<0.10,>=0.9->finrl) (0.13.2)
# Requirement already satisfied: empyrical>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from pyfolio<0.10,>=0.9->finrl) (0.5.5)
# Requirement already satisfied: cvxpy>=1.1.19 in /usr/local/lib/python3.11/dist-packages (from pyportfolioopt<2,>=1->finrl) (1.6.2)
# Requirement already satisfied: ecos<3.0.0,>=2.0.14 in /usr/local/lib/python3.11/dist-packages (from pyportfolioopt<2,>=1->finrl) (2.0.14)
# Requirement already satisfied: plotly<6.0.0,>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from pyportfolioopt<2,>=1->finrl) (5.24.1)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.11/dist-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl) (8.1.8)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl) (3.17.0)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.11/dist-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl) (4.23.0)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /usr/local/lib/python3.11/dist-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl) (4.25.6)
# Requirement already satisfied: aiosignal in /usr/local/lib/python3.11/dist-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl) (1.3.2)
# Requirement already satisfied: frozenlist in /usr/local/lib/python3.11/dist-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl) (1.5.0)
# Requirement already satisfied: aiohttp_cors in /usr/local/lib/python3.11/dist-packages (from ray[default,tune]<3,>=2->finrl) (0.7.0)
# Requirement already satisfied: colorful in /usr/local/lib/python3.11/dist-packages (from ray[default,tune]<3,>=2->finrl) (0.5.6)
# Requirement already satisfied: py-spy>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from ray[default,tune]<3,>=2->finrl) (0.4.0)
# Requirement already satisfied: grpcio>=1.42.0 in /usr/local/lib/python3.11/dist-packages (from ray[default,tune]<3,>=2->finrl) (1.70.0)
# Requirement already satisfied: opencensus in /usr/local/lib/python3.11/dist-packages (from ray[default,tune]<3,>=2->finrl) (0.11.4)
# Requirement already satisfied: prometheus_client>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from ray[default,tune]<3,>=2->finrl) (0.21.1)
# Requirement already satisfied: smart_open in /usr/local/lib/python3.11/dist-packages (from ray[default,tune]<3,>=2->finrl) (7.1.0)
# Requirement already satisfied: virtualenv!=20.21.1,>=20.0.24 in /usr/local/lib/python3.11/dist-packages (from ray[default,tune]<3,>=2->finrl) (20.29.2)
# Requirement already satisfied: tensorboardX>=1.9 in /usr/local/lib/python3.11/dist-packages (from ray[default,tune]<3,>=2->finrl) (2.6.2.2)
# Requirement already satisfied: pyarrow>=9.0.0 in /usr/local/lib/python3.11/dist-packages (from ray[default,tune]<3,>=2->finrl) (18.1.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from ray[default,tune]<3,>=2->finrl) (2024.10.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<2,>=1->finrl) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<2,>=1->finrl) (3.5.0)
# Requirement already satisfied: trio~=0.17 in /usr/local/lib/python3.11/dist-packages (from selenium<5,>=4->finrl) (0.29.0)
# Requirement already satisfied: trio-websocket~=0.9 in /usr/local/lib/python3.11/dist-packages (from selenium<5,>=4->finrl) (0.12.2)
# Requirement already satisfied: typing_extensions~=4.9 in /usr/local/lib/python3.11/dist-packages (from selenium<5,>=4->finrl) (4.12.2)
# Requirement already satisfied: gymnasium<1.1.0,>=0.29.1 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl) (1.0.0)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl) (2.5.1+cu124)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl) (3.1.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl) (4.11.0.86)
# Requirement already satisfied: pygame in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl) (2.6.1)
# Requirement already satisfied: tensorboard>=2.9.1 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl) (2.18.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl) (5.9.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl) (4.67.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl) (13.9.4)
# Requirement already satisfied: ale-py>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl) (0.10.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]>=2.0.0a5->finrl) (11.1.0)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.11/dist-packages (from webdriver-manager<5,>=4->finrl) (1.0.1)
# Requirement already satisfied: psycopg2-binary<2.10,>=2.9 in /usr/local/lib/python3.11/dist-packages (from wrds<4,>=3->finrl) (2.9.10)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.11/dist-packages (from yfinance<0.3,>=0.2->finrl) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from yfinance<0.3,>=0.2->finrl) (4.3.6)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.11/dist-packages (from yfinance<0.3,>=0.2->finrl) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.11/dist-packages (from yfinance<0.3,>=0.2->finrl) (3.17.9)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.11/dist-packages (from yfinance<0.3,>=0.2->finrl) (4.13.3)
# Requirement already satisfied: th in /usr/local/lib/python3.11/dist-packages (from elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git->finrl) (0.4.1)
# Requirement already satisfied: pycares>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from aiodns>=1.1.1->ccxt<4,>=3->finrl) (4.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl) (2.4.6)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl) (25.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl) (0.3.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.11.1->yfinance<0.3,>=0.2->finrl) (2.6)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography>=2.6.1->ccxt<4,>=3->finrl) (1.17.1)
# Requirement already satisfied: osqp>=0.6.2 in /usr/local/lib/python3.11/dist-packages (from cvxpy>=1.1.19->pyportfolioopt<2,>=1->finrl) (0.6.7.post3)
# Requirement already satisfied: clarabel>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from cvxpy>=1.1.19->pyportfolioopt<2,>=1->finrl) (0.10.0)
# Requirement already satisfied: scs>=3.2.4.post1 in /usr/local/lib/python3.11/dist-packages (from cvxpy>=1.1.19->pyportfolioopt<2,>=1->finrl) (3.2.7.post2)
# Requirement already satisfied: pandas-datareader>=0.2 in /usr/local/lib/python3.11/dist-packages (from empyrical>=0.5.0->pyfolio<0.10,>=0.9->finrl) (0.10.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.1.0,>=0.29.1->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl) (0.0.4)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.11/dist-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.11/dist-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl) (3.0.50)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl) (4.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl) (2.8.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly<6.0.0,>=5.0.0->pyportfolioopt<2,>=1->finrl) (9.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.0.3->alpaca-py<0.38,>=0.37->finrl) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.0.3->alpaca-py<0.38,>=0.37->finrl) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.30.0->alpaca-py<0.38,>=0.37->finrl) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.30.0->alpaca-py<0.38,>=0.37->finrl) (3.10)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy>=1.2.8->jqdatasdk<2,>=1->finrl) (3.1.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl) (1.4.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl) (3.1.3)
# Requirement already satisfied: Cython>=3.0.10 in /usr/local/lib/python3.11/dist-packages (from thriftpy2!=0.5.1,>=0.3.9->jqdatasdk<2,>=1->finrl) (3.0.12)
# Requirement already satisfied: ply<4.0,>=3.4 in /usr/local/lib/python3.11/dist-packages (from thriftpy2!=0.5.1,>=0.3.9->jqdatasdk<2,>=1->finrl) (3.11)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl) (3.1.5)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl) (1.3.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.11/dist-packages (from trio~=0.17->selenium<5,>=4->finrl) (2.4.0)
# Requirement already satisfied: outcome in /usr/local/lib/python3.11/dist-packages (from trio~=0.17->selenium<5,>=4->finrl) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from trio~=0.17->selenium<5,>=4->finrl) (1.3.1)
# Requirement already satisfied: wsproto>=0.14 in /usr/local/lib/python3.11/dist-packages (from trio-websocket~=0.9->selenium<5,>=4->finrl) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from urllib3[socks]<3,>=1.26->selenium<5,>=4->finrl) (1.7.1)
# Requirement already satisfied: distlib<1,>=0.3.7 in /usr/local/lib/python3.11/dist-packages (from virtualenv!=20.21.1,>=20.0.24->ray[default,tune]<3,>=2->finrl) (0.3.9)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema->ray<3,>=2->ray[default,tune]<3,>=2->finrl) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema->ray<3,>=2->ray[default,tune]<3,>=2->finrl) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema->ray<3,>=2->ray[default,tune]<3,>=2->finrl) (0.23.1)
# Requirement already satisfied: opencensus-context>=0.1.3 in /usr/local/lib/python3.11/dist-packages (from opencensus->ray[default,tune]<3,>=2->finrl) (0.1.3)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from opencensus->ray[default,tune]<3,>=2->finrl) (2.24.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->stable-baselines3[extra]>=2.0.0a5->finrl) (3.0.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart_open->ray[default,tune]<3,>=2->finrl) (1.17.2)
# Requirement already satisfied: niltype<2.0,>=0.3 in /usr/local/lib/python3.11/dist-packages (from th->elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git->finrl) (1.0.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography>=2.6.1->ccxt<4,>=3->finrl) (2.22)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl) (1.68.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl) (1.26.0)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl) (2.27.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl) (0.8.4)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]>=2.0.0a5->finrl) (0.1.2)
# Requirement already satisfied: qdldl in /usr/local/lib/python3.11/dist-packages (from osqp>=0.6.2->cvxpy>=1.1.19->pyportfolioopt<2,>=1->finrl) (0.1.7.post5)
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/dist-packages (from pandas-datareader>=0.2->empyrical>=0.5.0->pyfolio<0.10,>=0.9->finrl) (5.3.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl) (0.2.13)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl) (3.0.2)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium<5,>=4->finrl) (0.14.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl) (4.9)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl) (0.6.1)

# %% [markdown]
# **Import Libraries**

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt
import seaborn as sns

# FinRL Libraries
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer
from finrl.config import INDICATORS

# %%
pip install yfinance
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.11/dist-packages (0.2.54)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.11/dist-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.11/dist-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.11/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from yfinance) (4.3.6)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.11/dist-packages (from yfinance) (2025.1)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.11/dist-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.11/dist-packages (from yfinance) (3.17.9)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.11/dist-packages (from yfinance) (4.13.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (4.12.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.3.0->yfinance) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yfinance) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yfinance) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31->yfinance) (2025.1.31)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)

# %% [markdown]
# **Manually Fetch Stock Data**

# %%
import yfinance as yf

# Define the stock symbol (e.g., Apple Inc. - AAPL)
ticker = "AAPL"

# Fetch data
stock = yf.Ticker(ticker)

# Get historical market data (last 1 year by default)
historical_data = stock.history(period="1y")

# Display the first few rows
print(historical_data.head())

# Get current stock price
current_price = stock.info["currentPrice"]
print(f"Current Price of {ticker}: ${current_price}")
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-03-01 00:00:00-05:00  178.706175  179.681565  176.546375  178.815659
# 2024-03-04 00:00:00-05:00  175.322153  176.068628  172.973243  174.277100
# 2024-03-05 00:00:00-05:00  169.957487  171.231471  168.822845  169.320496
# 2024-03-06 00:00:00-05:00  170.256080  170.435242  167.887261  168.325195
# 2024-03-07 00:00:00-05:00  168.355038  169.927615  167.698152  168.205750
#
#                              Volume  Dividends  Stock Splits
# Date
# 2024-03-01 00:00:00-05:00  73488000        0.0           0.0
# 2024-03-04 00:00:00-05:00  81510100        0.0           0.0
# 2024-03-05 00:00:00-05:00  95132400        0.0           0.0
# 2024-03-06 00:00:00-05:00  68587700        0.0           0.0
# 2024-03-07 00:00:00-05:00  71765100        0.0           0.0
# Current Price of AAPL: $241.395

# %%
# Define date range
start_date = "2019-01-01"
end_date = "2019-12-31"

# List of stock tickers
ticker_list = [
    "MMM", "AOS", "ABT", "ABBV", "ACN", "ATVI", "ADBE", "AMD", "AES", "AFL",
    "A", "APD", "AKAM", "ALB", "ARE", "ALGN", "ALLE", "LNT", "ALL", "GOOGL",
    "GOOG", "AMZN", "AMCR", "AEE", "AAL", "AEP", "AXP", "AIG", "AMT", "AWK",
    "AMP", "ABC", "AME", "AMGN", "ADI", "ANSS", "AON", "APA", "AAPL", "AMAT",
    "APTV", "ACGL", "ADM", "ANET", "AJG", "AIZ", "T", "ATO", "ADSK", "ADP",
    "AZO", "AVB", "BKR", "BALL", "BAC", "BBWI", "BAX", "BDX", "BRK.B", "BBY",
    "BIO", "TECH", "BIIB", "BLK", "BA", "BKNG", "BWA", "BXP", "BSX", "BMY",
    "AVGO", "BR", "BRO", "BF.B", "CHRW", "CDNS", "CZR", "CPT", "CPB", "COF",
    "CAH", "KMX", "CCL", "CARR", "CTLT", "CAT", "CBOE", "CBRE", "CDW", "CE",
    "CNC", "CNP", "CDAY", "CF", "CRL", "SCHW", "CHTR", "CVX", "CMG", "CB",
    "CHD", "CI", "CINF", "CTAS", "CSCO", "C", "CFG", "CLX", "CME", "CMS",
    "KO", "CTSH", "CL", "CMCSA", "CMA", "CAG", "COP", "ED", "STZ", "GLW",
    "CTVA", "COST", "CTRA", "CCI", "CSX", "CMI", "CVS", "DHI", "DHR", "DRI",
    "DVA", "DE", "DAL", "XRAY", "DVN", "DXCM", "FANG", "DLR", "DFS", "DIS",
    "DG", "DPZ", "DOV", "DOW", "DTE", "DUK", "DRE", "DD", "DXC", "EMN", "ETN",
    "EBAY", "ECL", "EIX", "EW", "EA", "EMR", "ENPH", "ETR", "EOG", "EPAM",
    "EFX", "EQIX", "EQR", "ESS", "EL", "ETSY", "RE", "EVRG", "ES", "EXC",
    "EXPE", "EXPD", "EXR", "XOM", "FFIV", "FDS", "FAST", "FRT", "FDX", "FITB",
    "FRC", "FE", "FIS", "FISV", "FLT", "FMC", "F", "FTNT", "FTV", "FBHS",
    "FOXA", "FOX", "BEN", "FCX", "GRMN", "IT", "GE", "GNRC", "GD", "GEHC",
    "GIS", "GM", "GPC", "GILD", "GL", "GPN", "GS", "HAL", "HBI", "HIG", "HAS",
    "HCA", "PEAK", "HSIC", "HSY", "HES", "HPE", "HLT", "HOLX", "HD", "HON",
    "HRL", "HST", "HWM", "HPQ", "HUM", "HBAN", "HII", "IBM", "IEX", "IDXX",
    "ITW", "ILMN", "INCY", "IR", "INTC", "ICE", "IP", "IPG", "IFF", "INTU",
    "ISRG", "IVZ", "INVH", "IQV", "IRM", "JBHT", "JKHY", "J", "JNJ", "JCI",
    "JPM", "JNPR", "K", "KDP", "KEY", "KEYS", "KMB", "KIM", "KMI", "KLAC",
    "KHC", "KR", "LHX", "LH", "LRCX", "LW", "LVS", "LDOS", "LEN", "LLY",
    "LNC", "LIN", "LYV", "LKQ", "LMT", "L", "LOW", "LUMN", "LYB", "MTB",
    "MRO", "MPC", "MKTX", "MAR", "MMC", "MLM", "MAS", "MA", "MTCH", "MKC",
    "MCD", "MCK", "MDT", "MRK", "META", "MET", "MTD", "MGM", "MCHP", "MU",
    "MSFT", "MAA", "MRNA", "MHK", "MOH", "TAP", "MDLZ", "MPWR", "MNST", "MCO",
    "MS", "MOS", "MSI", "MSCI", "NDAQ", "NTAP", "NFLX", "NWL", "NEM", "NWSA",
    "NWS", "NEE", "NKE", "NI", "NDSN", "NSC", "NTRS", "NOC", "NLOK", "NCLH",
    "NRG", "NUE", "NVDA", "NVR", "NXPI", "ORLY", "OXY", "ODFL", "OMC", "ON",
    "OKE", "ORCL", "OGN", "OTIS", "PCAR", "PKG", "PARA", "PH", "PAYX", "PAYC",
    "PYPL", "PENN", "PNR", "PBCT", "PEP", "PKI", "PFE", "PM", "PSX", "PNW",
    "PXD", "PNC", "POOL", "PPG", "PPL", "PFG", "PG", "PGR", "PLD", "PRU",
    "PTC", "PEG", "PSA", "PHM", "QRVO", "QCOM", "PWR", "DGX", "RL", "RJF",
    "RTX", "O", "REG", "REGN", "RF", "RSG", "RMD"]

# Define the required column format
expected_columns = ["Date", "Open", "High", "Low", "Close", "Adj Close", "Volume", "Ticker"]

# Initialize an empty DataFrame
df_list = []

# Loop through each ticker and fetch data separately
for ticker in ticker_list:
    try:
        stock_data = yf.download(ticker, start=start_date, end=end_date)
        stock_data["Ticker"] = ticker  # Add a column for the ticker symbol
        stock_data.reset_index(inplace=True)  #  date is a column
        df_list.append(stock_data)
        print(f" Successfully fetched data for {ticker}")
    except Exception as e:
        print(f" Error fetching data for {ticker}: {e}")

# Combine all stock data into one DataFrame
df = pd.concat(df_list, ignore_index=True)

# Print the actual column names in the DataFrame for debugging
print("Actual DataFrame columns:", df.columns)

# Ensure column order is consistent
# If 'Adj Close' is not found, try 'Adj_Close' or check for other variations
df = df[[c for c in expected_columns if c in df.columns]] # Select only columns present in the DataFrame


# Drop missing values (if any)
df.dropna(inplace=True)

# Display final dataset
print(df.head())
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for MMM
#  Successfully fetched data for AOS
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for ABT
#  Successfully fetched data for ABBV
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for ACN
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ATVI']: YFTzMissingError('possibly delisted; no timezone found')
#  Successfully fetched data for ATVI
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for ADBE
#  Successfully fetched data for AMD
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for AES
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for AFL
#  Successfully fetched data for A
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for APD
#  Successfully fetched data for AKAM
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for ALB
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for ARE
#  Successfully fetched data for ALGN
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for ALLE
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for LNT
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for ALL
#  Successfully fetched data for GOOGL
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for GOOG
#  Successfully fetched data for AMZN
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for AMCR
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for AEE
#  Successfully fetched data for AAL
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for AEP
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for AXP
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for AIG
#  Successfully fetched data for AMT
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for AWK
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for AMP
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['ABC']: YFTzMissingError('possibly delisted; no timezone found')
#  Successfully fetched data for ABC
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for AME
#  Successfully fetched data for AMGN
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for ADI
#  Successfully fetched data for ANSS
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for AON
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for APA
#  Successfully fetched data for AAPL
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for AMAT
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for APTV
#  Successfully fetched data for ACGL
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for ADM
#  Successfully fetched data for ANET
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for AJG
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for AIZ
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for T
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for ATO
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for ADSK
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for ADP
#  Successfully fetched data for AZO
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for AVB
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for BKR
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for BALL
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for BAC
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for BBWI
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for BAX
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for BDX
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BRK.B']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for BRK.B
#  Successfully fetched data for BBY
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for BIO
#  Successfully fetched data for TECH
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for BIIB
#  Successfully fetched data for BLK
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for BA
#  Successfully fetched data for BKNG
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for BWA
#  Successfully fetched data for BXP
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for BSX
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for BMY
#  Successfully fetched data for AVGO
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for BR
#  Successfully fetched data for BRO
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['BF.B']: YFPricesMissingError('possibly delisted; no price data found  (1d 2023-01-01 -> 2023-12-31)')
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for BF.B
#  Successfully fetched data for CHRW
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for CDNS
#  Successfully fetched data for CZR
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for CPT
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for CPB
#  Successfully fetched data for COF
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for CAH
#  Successfully fetched data for KMX
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for CCL
#  Successfully fetched data for CARR
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CTLT']: YFTzMissingError('possibly delisted; no timezone found')
#  Successfully fetched data for CTLT
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for CAT
#  Successfully fetched data for CBOE
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for CBRE
#  Successfully fetched data for CDW
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for CE
#  Successfully fetched data for CNC
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for CNP
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['CDAY']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for CDAY
#  Successfully fetched data for CF
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for CRL
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for SCHW
#  Successfully fetched data for CHTR
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for CVX
#  Successfully fetched data for CMG
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for CB
#  Successfully fetched data for CHD
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for CI
#  Successfully fetched data for CINF
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for CTAS
#  Successfully fetched data for CSCO
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for C
#  Successfully fetched data for CFG
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for CLX
#  Successfully fetched data for CME
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for CMS
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for KO
#  Successfully fetched data for CTSH
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for CL
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for CMCSA
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for CMA
#  Successfully fetched data for CAG
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for COP
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for ED
#  Successfully fetched data for STZ
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for GLW
#  Successfully fetched data for CTVA
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for COST
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for CTRA
#  Successfully fetched data for CCI
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for CSX
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for CMI
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for CVS
#  Successfully fetched data for DHI
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for DHR
#  Successfully fetched data for DRI
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for DVA
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for DE
#  Successfully fetched data for DAL
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for XRAY
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for DVN
#  Successfully fetched data for DXCM
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for FANG
#  Successfully fetched data for DLR
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for DFS
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for DIS
#  Successfully fetched data for DG
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for DPZ
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for DOV
#  Successfully fetched data for DOW
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for DTE
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for DUK
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['DRE']: YFTzMissingError('possibly delisted; no timezone found')
#  Successfully fetched data for DRE
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for DD
#  Successfully fetched data for DXC
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for EMN
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for ETN
#  Successfully fetched data for EBAY
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for ECL
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for EIX
#  Successfully fetched data for EW
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for EA
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for EMR
#  Successfully fetched data for ENPH
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for ETR
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for EOG
#  Successfully fetched data for EPAM
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for EFX
#  Successfully fetched data for EQIX
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for EQR
#  Successfully fetched data for ESS
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for EL
#  Successfully fetched data for ETSY
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['RE']: YFTzMissingError('possibly delisted; no timezone found')
#  Successfully fetched data for RE
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for EVRG
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for ES
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for EXC
#  Successfully fetched data for EXPE
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for EXPD
#  Successfully fetched data for EXR
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for XOM
#  Successfully fetched data for FFIV
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for FDS
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for FAST
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for FRT
#  Successfully fetched data for FDX
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for FITB
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['FRC']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for FRC
#  Successfully fetched data for FE
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for FIS
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['FISV']: YFTzMissingError('possibly delisted; no timezone found')
#  Successfully fetched data for FISV
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['FLT']: YFTzMissingError('possibly delisted; no timezone found')
#  Successfully fetched data for FLT
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for FMC
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for F
#  Successfully fetched data for FTNT
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for FTV
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['FBHS']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for FBHS
#  Successfully fetched data for FOXA
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for FOX
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for BEN
#  Successfully fetched data for FCX
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for GRMN
#  Successfully fetched data for IT
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for GE
#  Successfully fetched data for GNRC
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for GD
#  Successfully fetched data for GEHC
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for GIS
#  Successfully fetched data for GM
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for GPC
#  Successfully fetched data for GILD
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for GL
#  Successfully fetched data for GPN
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for GS
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for HAL
#  Successfully fetched data for HBI
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for HIG
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for HAS
#  Successfully fetched data for HCA
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['PEAK']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for PEAK
#  Successfully fetched data for HSIC
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for HSY
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for HES
#  Successfully fetched data for HPE
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for HLT
#  Successfully fetched data for HOLX
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for HD
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for HON
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for HRL
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for HST
#  Successfully fetched data for HWM
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for HPQ
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for HUM
#  Successfully fetched data for HBAN
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for HII
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for IBM
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for IEX
#  Successfully fetched data for IDXX
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for ITW
#  Successfully fetched data for ILMN
#  Successfully fetched data for INCY
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for IR
#  Successfully fetched data for INTC
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for ICE
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for IP
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for IPG
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for IFF
#  Successfully fetched data for INTU
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for ISRG
#  Successfully fetched data for IVZ
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for INVH
#  Successfully fetched data for IQV
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for IRM
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for JBHT
#  Successfully fetched data for JKHY
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for J
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for JNJ
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for JCI
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for JPM
#  Successfully fetched data for JNPR
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for K
#  Successfully fetched data for KDP
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for KEY
#  Successfully fetched data for KEYS
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for KMB
#  Successfully fetched data for KIM
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for KMI
#  Successfully fetched data for KLAC
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for KHC
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for KR
#  Successfully fetched data for LHX
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for LH
#  Successfully fetched data for LRCX
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for LW
#  Successfully fetched data for LVS
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for LDOS
#  Successfully fetched data for LEN
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for LLY
#  Successfully fetched data for LNC
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for LIN
#  Successfully fetched data for LYV
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for LKQ
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for LMT
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for L
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for LOW
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for LUMN
#  Successfully fetched data for LYB
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for MTB
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['MRO']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for MRO
#  Successfully fetched data for MPC
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for MKTX
#  Successfully fetched data for MAR
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for MMC
#  Successfully fetched data for MLM
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for MAS
#  Successfully fetched data for MA
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for MTCH
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for MKC
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for MCD
#  Successfully fetched data for MCK
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for MDT
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for MRK
#  Successfully fetched data for META
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for MET
#  Successfully fetched data for MTD
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for MGM
#  Successfully fetched data for MCHP
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for MU
#  Successfully fetched data for MSFT
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for MAA
#  Successfully fetched data for MRNA
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for MHK
#  Successfully fetched data for MOH
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for TAP
#  Successfully fetched data for MDLZ
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for MPWR
#  Successfully fetched data for MNST
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for MCO
#  Successfully fetched data for MS
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for MOS
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for MSI
#  Successfully fetched data for MSCI
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for NDAQ
#  Successfully fetched data for NTAP
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for NFLX
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for NWL
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for NEM
#  Successfully fetched data for NWSA
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for NWS
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for NEE
#  Successfully fetched data for NKE
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for NI
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for NDSN
#  Successfully fetched data for NSC
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for NTRS
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for NOC
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['NLOK']: YFTzMissingError('possibly delisted; no timezone found')
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for NLOK
#  Successfully fetched data for NCLH
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for NRG
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for NUE
#  Successfully fetched data for NVDA
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for NVR
#  Successfully fetched data for NXPI
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for ORLY
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for OXY
#  Successfully fetched data for ODFL
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for OMC
#  Successfully fetched data for ON
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for OKE
#  Successfully fetched data for ORCL
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for OGN
#  Successfully fetched data for OTIS
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for PCAR
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for PKG
#  Successfully fetched data for PARA
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for PH
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for PAYX
#  Successfully fetched data for PAYC
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for PYPL
#  Successfully fetched data for PENN
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for PNR
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['PBCT']: YFTzMissingError('possibly delisted; no timezone found')
#  Successfully fetched data for PBCT
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for PEP
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['PKI']: YFTzMissingError('possibly delisted; no timezone found')
#  Successfully fetched data for PKI
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for PFE
#  Successfully fetched data for PM
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for PSX
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for PNW
# [*********************100%***********************]  1 of 1 completed
# ERROR:yfinance:
# 1 Failed download:
# ERROR:yfinance:['PXD']: YFTzMissingError('possibly delisted; no timezone found')
#  Successfully fetched data for PXD
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for PNC
#  Successfully fetched data for POOL
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for PPG
#  Successfully fetched data for PPL
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for PFG
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for PG
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for PGR
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for PLD
#  Successfully fetched data for PRU
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for PTC
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for PEG
#  Successfully fetched data for PSA
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for PHM
#  Successfully fetched data for QRVO
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for QCOM
#  Successfully fetched data for PWR
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for DGX
#  Successfully fetched data for RL
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for RJF
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for RTX
#  Successfully fetched data for O
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for REG
#  Successfully fetched data for REGN
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for RF
#  Successfully fetched data for RSG
# [*********************100%***********************]  1 of 1 completed
#  Successfully fetched data for RMD
# Actual DataFrame columns: MultiIndex([(  'Date',    ''),
#             ( 'Close', 'MMM'),
#             (  'High', 'MMM'),
#             (   'Low', 'MMM'),
#             (  'Open', 'MMM'),
#             ('Volume', 'MMM'),
#             ('Ticker',    ''),
#             ( 'Close', 'AOS'),
#             (  'High', 'AOS'),
#             (   'Low', 'AOS'),
#             ...
#             ( 'Close', 'RSG'),
#             (  'High', 'RSG'),
#             (   'Low', 'RSG'),
#             (  'Open', 'RSG'),
#             ('Volume', 'RSG'),
#             ( 'Close', 'RMD'),
#             (  'High', 'RMD'),
#             (   'Low', 'RMD'),
#             (  'Open', 'RMD'),
#             ('Volume', 'RMD')],
#            names=['Price', 'Ticker'], length=1965)
# Empty DataFrame
# Columns: [(Date, ), (Open, MMM), (Open, AOS), (Open, ABT), (Open, ABBV), (Open, ACN), (Open, ATVI), (Open, ADBE), (Open, AMD), (Open, AES), (Open, AFL), (Open, A), (Open, APD), (Open, AKAM), (Open, ALB), (Open, ARE), (Open, ALGN), (Open, ALLE), (Open, LNT), (Open, ALL), (Open, GOOGL), (Open, GOOG), (Open, AMZN), (Open, AMCR), (Open, AEE), (Open, AAL), (Open, AEP), (Open, AXP), (Open, AIG), (Open, AMT), (Open, AWK), (Open, AMP), (Open, ABC), (Open, AME), (Open, AMGN), (Open, ADI), (Open, ANSS), (Open, AON), (Open, APA), (Open, AAPL), (Open, AMAT), (Open, APTV), (Open, ACGL), (Open, ADM), (Open, ANET), (Open, AJG), (Open, AIZ), (Open, T), (Open, ATO), (Open, ADSK), (Open, ADP), (Open, AZO), (Open, AVB), (Open, BKR), (Open, BALL), (Open, BAC), (Open, BBWI), (Open, BAX), (Open, BDX), (Open, BRK.B), (Open, BBY), (Open, BIO), (Open, TECH), (Open, BIIB), (Open, BLK), (Open, BA), (Open, BKNG), (Open, BWA), (Open, BXP), (Open, BSX), (Open, BMY), (Open, AVGO), (Open, BR), (Open, BRO), (Open, BF.B), (Open, CHRW), (Open, CDNS), (Open, CZR), (Open, CPT), (Open, CPB), (Open, COF), (Open, CAH), (Open, KMX), (Open, CCL), (Open, CARR), (Open, CTLT), (Open, CAT), (Open, CBOE), (Open, CBRE), (Open, CDW), (Open, CE), (Open, CNC), (Open, CNP), (Open, CDAY), (Open, CF), (Open, CRL), (Open, SCHW), (Open, CHTR), (Open, CVX), (Open, CMG), ...]
# Index: []
#
# [0 rows x 1965 columns]

# %% [markdown]
# **Flatten MultiIndex and Standardize Columns**

# %%
# Fetch all tickers at once
stock_data = yf.download(ticker_list, start=start_date, end=end_date, group_by='ticker')

# Flatten MultiIndex and reformat DataFrame
flattened_data = []

for ticker in ticker_list:
    temp_df = stock_data[ticker].copy()
    temp_df["Ticker"] = ticker  # Add a ticker column
    temp_df.reset_index(inplace=True)  # Make date a column
    flattened_data.append(temp_df)

# Combine all individual DataFrames
df = pd.concat(flattened_data, ignore_index=True)

# Rename columns for consistency
df.rename(columns={"Adj Close": "Adj_Close"}, inplace=True)

# Display the first few rows
print(df.head())
# Out:
# [*********************100%***********************]  389 of 389 completed
# ERROR:yfinance:
# 18 Failed downloads:
# ERROR:yfinance:['CDAY', 'ABC', 'MRO', 'FRC', 'FISV', 'NLOK', 'PBCT', 'CTLT', 'FBHS', 'ATVI', 'BRK.B', 'DRE', 'PXD', 'PEAK', 'PKI', 'RE', 'FLT']: YFTzMissingError('possibly delisted; no timezone found')
# ERROR:yfinance:['BF.B']: YFPricesMissingError('possibly delisted; no price data found  (1d 2023-01-01 -> 2023-12-31)')
# Price       Date       Open       High        Low      Close     Volume  \
# 0     2023-01-03  92.148575  92.997871  91.276529  92.868958  3124909.0
# 1     2023-01-04  93.536271  95.007370  93.050959  94.901207  3312561.0
# 2     2023-01-05  94.188399  94.461386  92.861374  93.240524  3117494.0
# 3     2023-01-06  94.529642  96.402648  93.839594  96.091743  2890732.0
# 4     2023-01-09  96.304069  98.169484  95.629181  96.144821  3434075.0
#
# Price Ticker  Adj_Close
# 0        MMM        NaN
# 1        MMM        NaN
# 2        MMM        NaN
# 3        MMM        NaN
# 4        MMM        NaN

# %% [markdown]
# **Preprocessing**

# %%
# Load your stock data (assuming df is already fetched)
df = df.dropna()  # Drop missing values (alternative: df.fillna(method='ffill'))

# Convert Date to datetime format
df['Date'] = pd.to_datetime(df['Date'])

# Sort data for consistency
df = df.sort_values(by=['Ticker', 'Date']).reset_index(drop=True)

# Function to calculate Moving Averages
def moving_average(df, window=10):
    df[f'MA_{window}'] = df.groupby('Ticker')['Close'].transform(lambda x: x.rolling(window=window).mean())

# Apply Moving Averages
moving_average(df, window=10)
moving_average(df, window=50)

# Calculate Relative Strength Index (RSI)
def compute_rsi(df, window=14):
    delta = df.groupby('Ticker')['Close'].diff()
    gain = (delta.where(delta > 0, 0)).rolling(window=window).mean()
    loss = (-delta.where(delta < 0, 0)).rolling(window=window).mean()
    rs = gain / loss
    df[f'RSI_{window}'] = 100 - (100 / (1 + rs))

compute_rsi(df, window=14)

# Calculate MACD (Moving Average Convergence Divergence)
def compute_macd(df):
    short_ema = df.groupby('Ticker')['Close'].transform(lambda x: x.ewm(span=12, adjust=False).mean())
    long_ema = df.groupby('Ticker')['Close'].transform(lambda x: x.ewm(span=26, adjust=False).mean())
    df['MACD'] = short_ema - long_ema
    df['MACD_Signal'] = df.groupby('Ticker')['MACD'].transform(lambda x: x.ewm(span=9, adjust=False).mean())

compute_macd(df)

# Calculate Bollinger Bands
def compute_bollinger_bands(df, window=20):
    rolling_mean = df.groupby('Ticker')['Close'].transform(lambda x: x.rolling(window=window).mean())
    rolling_std = df.groupby('Ticker')['Close'].transform(lambda x: x.rolling(window=window).std())
    df['BB_Upper'] = rolling_mean + (rolling_std * 2)
    df['BB_Lower'] = rolling_mean - (rolling_std * 2)

moving_average(df, window=10)
moving_average(df, window=50)
compute_rsi(df, window=14)
compute_macd(df)

compute_bollinger_bands(df, window=20)

# Normalize price values for better performance in models
df['Close_Norm'] = df.groupby('Ticker')['Close'].transform(lambda x: (x - x.min()) / (x.max() - x.min()))

# Save preprocessed data
df.to_csv('preprocessed_stock_data.csv', index=False)

# Display first few rows
print(df.head())
# Out:
# Empty DataFrame
# Columns: [Date, Open, High, Low, Close, Volume, Ticker, Adj_Close, MA_10, MA_50, RSI_14, MACD, MACD_Signal, BB_Upper, BB_Lower, Close_Norm]
# Index: []

# %%
# Remove initial rows with NaN values from moving averages, RSI, and Bollinger Bands
df = df.dropna().reset_index(drop=True)

# %%
# Display first few rows
print(df.head())
# Out:
# Empty DataFrame
# Columns: [Date, Open, High, Low, Close, Volume, Ticker, Adj_Close, MA_10, MA_50, RSI_14, MACD, MACD_Signal, BB_Upper, BB_Lower, Close_Norm]
# Index: []

# %%
from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
import pandas as pd

# %% [markdown]
# **Implement Risk Management Model (With PPO)**

# %%
# Fetch VIX data
vix_data = yf.download("^VIX", start=start_date, end=end_date)

# Flatten MultiIndex in vix_data if present
if isinstance(vix_data.columns, pd.MultiIndex):
    vix_data.columns = [col[0] for col in vix_data.columns]  # Keep only first level

# Ensure 'date' column exists and is properly formatted
# Check if 'level_0' already exists as a column, if so, drop it before reset_index
if 'level_0' in vix_data.columns:
    vix_data = vix_data.drop(columns=['level_0'])
vix_data = vix_data.reset_index() # Reset the index after potentially dropping 'level_0'
vix_data.rename(columns={"Date": "date"}, inplace=True)
vix_data["date"] = pd.to_datetime(vix_data["date"])

# Ensure df["Date"] is also formatted correctly
# Changed 'date' to 'Date' to match the existing column name
df["Date"] = pd.to_datetime(df["Date"])

# Debugging: Print column names before merging
print("df columns:", df.columns)
print("vix_data columns:", vix_data.columns)

# Merge VIX data with stock data using 'Date' from df and 'date' from vix_data
df = pd.merge(df, vix_data, left_on="Date", right_on="date", how="left")  # Changed here

print(" Merge successful!")
# Out:
# [*********************100%***********************]  1 of 1 completed
# df columns: Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Ticker', 'Adj_Close',
#        'MA_10', 'MA_50', 'RSI_14', 'MACD', 'MACD_Signal', 'BB_Upper',
#        'BB_Lower', 'Close_Norm'],
#       dtype='object', name='Price')
# vix_data columns: Index(['date', 'Close', 'High', 'Low', 'Open', 'Volume'], dtype='object')
#  Merge successful!

# %%
# %whos
# Out:
# Variable                  Type         Data/Info
# ------------------------------------------------
# FeatureEngineer           type         <class 'finrl.meta.prepro<...>cessors.FeatureEngineer'>
# INDICATORS                list         n=8
# StockTradingEnv           type         <class 'finrl.meta.env_st<...>trading.StockTradingEnv'>
# YahooDownloader           type         <class 'finrl.meta.prepro<...>nloader.YahooDownloader'>
# compute_bollinger_bands   function     <function compute_bolling<...>_bands at 0x7cc253a9c220>
# compute_macd              function     <function compute_macd at 0x7cc253a9c0e0>
# compute_rsi               function     <function compute_rsi at 0x7cc253c6b740>
# current_price             float        241.395
# df                        DataFrame    Empty DataFrame\nColumns:<...>\n\n[0 rows x 22 columns]
# df_list                   list         n=389
# end_date                  str          2023-12-31
# expected_columns          list         n=8
# flattened_data            list         n=389
# historical_data           DataFrame                             <...>n\n[250 rows x 7 columns]
# moving_average            function     <function moving_average at 0x7cc3a7f8fd80>
# np                        module       <module 'numpy' from '/us<...>kages/numpy/__init__.py'>
# pd                        module       <module 'pandas' from '/u<...>ages/pandas/__init__.py'>
# plt                       module       <module 'matplotlib.pyplo<...>es/matplotlib/pyplot.py'>
# sns                       module       <module 'seaborn' from '/<...>ges/seaborn/__init__.py'>
# start_date                str          2023-01-01
# stock                     Ticker       yfinance.Ticker object <AAPL>
# stock_data                DataFrame    Ticker             IFF   <...>[250 rows x 1963 columns]
# temp_df                   DataFrame    Price       Date        O<...>n\n[250 rows x 7 columns]
# ticker                    str          RMD
# ticker_list               list         n=389
# vix_data                  DataFrame              date      Close<...>n\n[250 rows x 6 columns]
# yf                        module       <module 'yfinance' from '<...>es/yfinance/__init__.py'>

# %%
df_vix = vix_data.copy()

# %%
print("df_vix columns before processing:", df_vix.columns)
# Out:
# df_vix columns before processing: Index(['date', 'Close', 'High', 'Low', 'Open', 'Volume'], dtype='object')

# %%
print("df_vix columns:", df_vix.columns)
# Out:
# df_vix columns: Index(['date', 'Close', 'High', 'Low', 'Open', 'Volume'], dtype='object')

# %%
# vix_data columns: Index(['level_0', 'index', 'date', 'vix'], dtype='object')
# This line is not Python code, so no syntax correction is needed.  It appears to be output from a Python program.
pass

# %%
print("df_vix columns after renaming:", df_vix.columns)
# Out:
# df_vix columns after renaming: Index(['date', 'Close', 'High', 'Low', 'Open', 'Volume'], dtype='object')

# %%
df_vix = df_vix[["date", "Close"]]  # Ensure only required columns
df_vix.rename(columns={"Close": "vix"}, inplace=True)  # Rename 'Close' to 'vix'
df_vix.drop_duplicates(inplace=True)
df_vix.dropna(inplace=True)

# Merge with main dataset
df = df.merge(df_vix, on="date", how="left")

# Fill missing values
df["vix"] = df["vix"].ffill()

print(" Successfully merged VIX data!")
# Out:
#  Successfully merged VIX data!

# %%
import numpy as np
import pandas as pd
import gym
from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent
from stable_baselines3 import PPO
from stable_baselines3.common.logger import configure
import torch

# %%
def risk_adjusted_reward(trade_result, cash, portfolio_value):
    """
    Custom risk-adjusted reward function.
    - Applies penalties for high volatility, drawdowns, and risk factors.
    """
    reward = trade_result

    # Apply Stop-Loss Penalty (if losses exceed threshold, punish heavily)
    if trade_result < -0.02 * portfolio_value:  # 2% loss
        reward -= abs(trade_result) * 1.5

    # Apply Take-Profit Bonus (if gains exceed threshold, reward)
    if trade_result > 0.02 * portfolio_value:  # 2% gain
        reward += abs(trade_result) * 0.5

    # Apply Volatility Penalty (high VIX = higher risk)
    vix_penalty = df["vix"].iloc[-1] / 100  # Normalize VIX
    reward -= vix_penalty

    return reward

# %%
class StockTradingRiskEnv(StockTradingEnv):
    def __init__(self, df, **kwargs):
        super().__init__(df, **kwargs)

    def _calculate_reward(self, actions):
        """
        Override reward calculation with risk-adjusted function.
        """
        trade_result = self.account_information["portfolio_value"][-1] - self.account_information["portfolio_value"][-2]
        portfolio_value = self.account_information["portfolio_value"][-1]
        cash = self.account_information["cash"][-1]
        return risk_adjusted_reward(trade_result, cash, portfolio_value)

# %% [markdown]
# **StockTradingRiskEnv**
#
#
# Risk-Adjusted Trading Environment

# %%
class StockTradingRiskEnv(StockTradingEnv):
    def __init__(self, df, stock_dim, hmax, initial_amount, num_stock_shares,
                 buy_cost_pct, sell_cost_pct, reward_scaling, state_space,
                 action_space, tech_indicator_list):
        super().__init__(df=df, stock_dim=stock_dim, hmax=hmax,
                         initial_amount=initial_amount, num_stock_shares=num_stock_shares,
                         buy_cost_pct=buy_cost_pct, sell_cost_pct=sell_cost_pct,
                         reward_scaling=reward_scaling, state_space=state_space,
                         action_space=action_space, tech_indicator_list=tech_indicator_list)

    def _calculate_reward(self, actions):
        """
        Override reward calculation with risk-adjusted function.
        """
        trade_result = self.account_information["portfolio_value"][-1] - self.account_information["portfolio_value"][-2]
        portfolio_value = self.account_information["portfolio_value"][-1]
        cash = self.account_information["cash"][-1]
        return risk_adjusted_reward(trade_result, cash, portfolio_value)

# %%
# Instead of directly accessing df["Close"], check if the column exists first:
if "Close" in df.columns and isinstance(df["Close"], np.float64):
    df["Close"] = pd.Series([df["Close"]])

# Alternatively, if you expect the column to be named 'close' (lowercase):
if "close" in df.columns and isinstance(df["close"], np.float64):
    df["close"] = pd.Series([df["close"]])

# %%
print(df.head())  # Check DataFrame structure
print(df.dtypes)  # Ensure 'close' is a float and a Pandas Series
# Out:
# Empty DataFrame
# Columns: [Date, Open_x, High_x, Low_x, Close_x, Volume_x, Ticker, Adj_Close, MA_10, MA_50, RSI_14, MACD, MACD_Signal, BB_Upper, BB_Lower, Close_Norm, date, Close_y, High_y, Low_y, Open_y, Volume_y, vix]
# Index: []
#
# [0 rows x 23 columns]
# Date           datetime64[ns]
# Open_x                float64
# High_x                float64
# Low_x                 float64
# Close_x               float64
# Volume_x              float64
# Ticker                 object
# Adj_Close             float64
# MA_10                 float64
# MA_50                 float64
# RSI_14                float64
# MACD                  float64
# MACD_Signal           float64
# BB_Upper              float64
# BB_Lower              float64
# Close_Norm            float64
# date           datetime64[ns]
# Close_y               float64
# High_y                float64
# Low_y                 float64
# Open_y                float64
# Volume_y                int64
# vix                   float64
# dtype: object

# %%
df = df.reset_index(drop=True)  # Ensure it's a clean DataFrame

# %%
print("Columns in df:", df.columns)  # Check column names
print("First few rows:\n", df.head())  # Check if 'close' is present
# Out:
# Columns in df: Index(['Date', 'Open_x', 'High_x', 'Low_x', 'Close_x', 'Volume_x', 'Ticker',
#        'Adj_Close', 'MA_10', 'MA_50', 'RSI_14', 'MACD', 'MACD_Signal',
#        'BB_Upper', 'BB_Lower', 'Close_Norm', 'date', 'Close_y', 'High_y',
#        'Low_y', 'Open_y', 'Volume_y', 'vix'],
#       dtype='object')
# First few rows:
#  Empty DataFrame
# Columns: [Date, Open_x, High_x, Low_x, Close_x, Volume_x, Ticker, Adj_Close, MA_10, MA_50, RSI_14, MACD, MACD_Signal, BB_Upper, BB_Lower, Close_Norm, date, Close_y, High_y, Low_y, Open_y, Volume_y, vix]
# Index: []
#
# [0 rows x 23 columns]

# %%
# List all column names to identify potential issues
print(df.columns.tolist())
# Out:
# ['Date', 'Open_x', 'High_x', 'Low_x', 'Close_x', 'Volume_x', 'Ticker', 'Adj_Close', 'MA_10', 'MA_50', 'RSI_14', 'MACD', 'MACD_Signal', 'BB_Upper', 'BB_Lower', 'Close_Norm', 'date', 'Close_y', 'High_y', 'Low_y', 'Open_y', 'Volume_y', 'vix']

# %%
df.rename(columns={"Close": "close"}, inplace=True)

# %%
if df.empty:
    print(" Warning: df is empty! Check data loading or merging steps.")
# Out:
#  Warning: df is empty! Check data loading or merging steps.

# %%
print(df_vix.head())  # Check if 'close' exists in df_vix
# Out:
#         date        vix
# 0 2023-01-03  22.900000
# 1 2023-01-04  22.010000
# 2 2023-01-05  22.459999
# 3 2023-01-06  21.129999
# 4 2023-01-09  21.969999

# %%
if "close" not in df_vix.columns:
    print("'close' column missing from df_vix. Available columns:", df_vix.columns)
# Out:
# 'close' column missing from df_vix. Available columns: Index(['date', 'vix'], dtype='object')

# %% [markdown]
# **state representation for the stock trading environment**

# %%
# Replace the `_initiate_state` method in StockTradingRiskEnv:
def _initiate_state(self):
    if isinstance(self.data.close, np.float64):
        state = (
            [self.initial_amount]
            + [self.data.close]  # Treat 'close' as a single value
            + self.num_stock_shares
            + sum(
                [
                    self.data[tech].values.tolist()
                    for tech in self.tech_indicator_list
                ],
                [],
            )
        )
        return state

    # Original logic for when 'close' is a Series
    else:
        state = (
            [self.initial_amount]
            + self.data.close.values.tolist()
            + self.num_stock_shares
            + sum(
                [
                    self.data[tech].values.tolist()
                    for tech in self.tech_indicator_list
                ],
                [],
            )
        )
        return state

# %%
# Ensure the 'Close' column is renamed to 'close' and the change is applied
df.rename(columns={"Close": "close"}, inplace=True)

# Now access the 'close' column
print(" Dataframe Type:", type(df))
# Check if 'close' column exists before accessing it
if 'close' in df.columns:
    print(" 'close' Column Type:", type(df["close"]))
    print("First 5 Rows of df:\n", df.head())
# Out:
#  Dataframe Type: <class 'pandas.core.frame.DataFrame'>

# %%
# Ensure the 'Close' column is renamed to 'close'
df.rename(columns={"Close": "close"}, inplace=True)

# Verify the column names after renaming
print(df.columns)

# Now you can proceed with your code using df["close"]
if 'close' in df.columns:  # Check if 'close' column exists before proceeding
    df["close"] = df["close"].astype(float)  # Ensure it's float
    df["close"] = df["close"].apply(lambda x: float(x))  # Explicit conversion
    df = df.copy()  # Ensure df is not a view of another dataframe

    print(" Verified 'close' column type:", type(df["close"]))
# Out:
# Index(['Date', 'Open_x', 'High_x', 'Low_x', 'Close_x', 'Volume_x', 'Ticker',
#        'Adj_Close', 'MA_10', 'MA_50', 'RSI_14', 'MACD', 'MACD_Signal',
#        'BB_Upper', 'BB_Lower', 'Close_Norm', 'date', 'Close_y', 'High_y',
#        'Low_y', 'Open_y', 'Volume_y', 'vix'],
#       dtype='object')

# %%
class StockTradingRiskEnv(StockTradingEnv):
    def __init__(self, df, **kwargs):
        super().__init__(df, **kwargs)
        self.data["close"] = pd.to_numeric(self.data["close"], errors="coerce")  # Convert inside class

# %%
print(" DataFrame Structure Check:")
print(type(df))  # Should be <class 'pandas.DataFrame'>
print(df.dtypes)  # Ensure 'close' is float or int
print(df.head())  # Preview the data
# Out:
#  DataFrame Structure Check:
# <class 'pandas.core.frame.DataFrame'>
# Date           datetime64[ns]
# Open_x                float64
# High_x                float64
# Low_x                 float64
# Close_x               float64
# Volume_x              float64
# Ticker                 object
# Adj_Close             float64
# MA_10                 float64
# MA_50                 float64
# RSI_14                float64
# MACD                  float64
# MACD_Signal           float64
# BB_Upper              float64
# BB_Lower              float64
# Close_Norm            float64
# date           datetime64[ns]
# Close_y               float64
# High_y                float64
# Low_y                 float64
# Open_y                float64
# Volume_y                int64
# vix                   float64
# dtype: object
# Empty DataFrame
# Columns: [Date, Open_x, High_x, Low_x, Close_x, Volume_x, Ticker, Adj_Close, MA_10, MA_50, RSI_14, MACD, MACD_Signal, BB_Upper, BB_Lower, Close_Norm, date, Close_y, High_y, Low_y, Open_y, Volume_y, vix]
# Index: []
#
# [0 rows x 23 columns]

# %%
import numpy as np
import gym
from gym import spaces

class StockTradingRiskEnv(gym.Env):
    """Stock Trading Environment with Risk Management"""

    def __init__(self, df, stock_dim, hmax, initial_amount, num_stock_shares,
                 buy_cost_pct, sell_cost_pct, reward_scaling,
                 state_space, action_space, tech_indicator_list):
        super(StockTradingRiskEnv, self).__init__()

        # Initialize stock data
        self.df = df
        self.stock_dim = stock_dim
        self.hmax = hmax
        self.initial_amount = initial_amount
        self.current_cash = initial_amount
        self.num_stock_shares = np.array(num_stock_shares)
        self.buy_cost_pct = buy_cost_pct
        self.sell_cost_pct = sell_cost_pct
        self.reward_scaling = reward_scaling
        self.tech_indicator_list = tech_indicator_list
        self.day = 0

        # Define action and observation space
        self.action_space = spaces.Box(low=-1, high=1, shape=(action_space,))
        self.observation_space = spaces.Box(
            low=-np.inf, high=np.inf, shape=(state_space,))

        # Load initial state
        self.data = self.df.iloc[self.day]

    def reset(self):
        """Resets the environment"""
        self.day = 0
        self.current_cash = self.initial_amount
        self.num_stock_shares = np.zeros(self.stock_dim)
        self.data = self.df.iloc[self.day]
        return self._get_observation()

    def step(self, action):
        """Executes an action (buy/sell/hold) and updates the environment"""
        self._trade(action)
        self.day += 1
        done = self.day >= len(self.df) - 1
        self.data = self.df.iloc[self.day] if not done else self.data
        reward = self._calculate_reward()
        return self._get_observation(), reward, done, {}

    def _trade(self, action):
        """Processes buy/sell actions"""
        for i in range(self.stock_dim):
            if action[i] > 0:  # Buy
                shares_to_buy = min(self.hmax, self.current_cash // self.data["close"])
                self.current_cash -= shares_to_buy * self.data["close"] * (1 + self.buy_cost_pct)
                self.num_stock_shares[i] += shares_to_buy

            elif action[i] < 0:  # Sell
                shares_to_sell = min(self.hmax, self.num_stock_shares[i])
                self.current_cash += shares_to_sell * self.data["close"] * (1 - self.sell_cost_pct)
                self.num_stock_shares[i] -= shares_to_sell

    def _calculate_reward(self):
        """Calculates reward based on portfolio value"""
        total_assets = self.current_cash + np.sum(self.num_stock_shares * self.data["close"])
        reward = total_assets - self.initial_amount
        return reward * self.reward_scaling

    def _get_observation(self):
        """Returns the current state representation"""
        stock_data = [self.data[indicator] for indicator in self.tech_indicator_list]
        return np.array([self.current_cash] + list(self.num_stock_shares) + stock_data)

    def render(self):
        """Prints the environment state"""
        print(f"Day: {self.day}, Cash: {self.current_cash}, Holdings: {self.num_stock_shares}")

# %%
import pandas as pd

# Example stock data (replace with real dataset)
data = {
    "date": pd.date_range(start="2023-01-01", periods=10, freq="D"),
    "close": [100, 102, 101, 105, 107, 110, 108, 109, 112, 115],
    "macd": np.random.randn(10),
    "rsi": np.random.randn(10),
    "cci": np.random.randn(10),
    "adx": np.random.randn(10),
    "vix": np.random.randn(10),
}
df = pd.DataFrame(data)

# Initialize Environment
env = StockTradingRiskEnv(
    df=df,
    stock_dim=1,
    hmax=10,
    initial_amount=1000,
    num_stock_shares=[0],
    buy_cost_pct=0.001,
    sell_cost_pct=0.001,
    reward_scaling=1e-4,
    state_space=6,
    action_space=1,
    tech_indicator_list=["macd", "rsi", "cci", "adx", "vix"]
)

# Test Environment
obs = env.reset()
done = False

while not done:
    action = np.random.uniform(-1, 1, size=(1,))  # Random buy/sell action
    obs, reward, done, _ = env.step(action)
    env.render()
# Out:
# Day: 1, Cash: 1000.0, Holdings: [0.]
# Day: 2, Cash: 81.08200000000011, Holdings: [9.]
# Day: 3, Cash: 81.08200000000011, Holdings: [9.]
# Day: 4, Cash: 81.08200000000011, Holdings: [9.]
# Day: 5, Cash: 81.08200000000011, Holdings: [9.]
# Day: 6, Cash: 81.08200000000011, Holdings: [9.]
# Day: 7, Cash: 1052.1100000000001, Holdings: [0.]
# Day: 8, Cash: 70.12900000000025, Holdings: [9.]
# Day: 9, Cash: 1077.121, Holdings: [0.]

# %% [markdown]
# **Train PPO Model in the StockTradingRiskEnv**

# %%
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv

# Define technical indicators
tech_indicators = ["macd", "rsi", "returns", "volatility", "value_at_risk"]

# Initialize the StockTradingRiskEnv
env = StockTradingRiskEnv(
    df=df,
    stock_dim=1,
    hmax=100,
    initial_amount=100000,
    num_stock_shares=[0],
    buy_cost_pct=0.001,
    sell_cost_pct=0.001,
    reward_scaling=1e-4,
    state_space=len(tech_indicators) + 2,  # Cash balance + stock holdings
    action_space=1,
    tech_indicator_list=tech_indicators
)

# %%
# !pip install 'shimmy>=2.0' # Install shimmy to bridge the gap between OpenAI Gym and Gymnasium
# Out:
# Collecting shimmy>=2.0
#   Downloading Shimmy-2.0.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.11/dist-packages (from shimmy>=2.0) (1.26.4)
# Requirement already satisfied: gymnasium>=1.0.0a1 in /usr/local/lib/python3.11/dist-packages (from shimmy>=2.0) (1.0.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium>=1.0.0a1->shimmy>=2.0) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium>=1.0.0a1->shimmy>=2.0) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium>=1.0.0a1->shimmy>=2.0) (0.0.4)
# Downloading Shimmy-2.0.0-py3-none-any.whl (30 kB)
# Installing collected packages: shimmy
# Successfully installed shimmy-2.0.0

# %%
# Wrap in a Dummy Vectorized Environment (Stable-Baselines3 requirement)
vec_env = DummyVecEnv([lambda: env])
# Out:
# /usr/local/lib/python3.11/dist-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(

# %%
tech_indicators = ["macd", "rsi", "returns", "volatility", "value_at_risk"]

# %%
import numpy as np
import gym
from gym import spaces

class StockTradingRiskEnv(gym.Env):
    """Stock Trading Environment with Risk Management"""

    def __init__(self, df, stock_dim, hmax, initial_amount, num_stock_shares,
                 buy_cost_pct, sell_cost_pct, reward_scaling,
                 state_space, action_space, tech_indicator_list):
        super(StockTradingRiskEnv, self).__init__()

        # Initialize stock data
        self.df = df
        self.stock_dim = stock_dim
        self.hmax = hmax
        self.initial_amount = initial_amount
        self.current_cash = initial_amount
        self.num_stock_shares = np.array(num_stock_shares)
        self.buy_cost_pct = buy_cost_pct
        self.sell_cost_pct = sell_cost_pct
        self.reward_scaling = reward_scaling
        self.tech_indicator_list = tech_indicator_list
        self.day = 0

        # Define action and observation space
        self.action_space = spaces.Box(low=-1, high=1, shape=(action_space,))
        self.observation_space = spaces.Box(
            low=-np.inf, high=np.inf, shape=(state_space,))

        # Load initial state
        self.data = self.df.iloc[self.day]

    def reset(self):
        """Resets the environment"""
        self.day = 0
        self.current_cash = self.initial_amount
        self.num_stock_shares = np.zeros(self.stock_dim)
        self.data = self.df.iloc[self.day]
        return self._get_observation()

    def step(self, action):
        """Executes an action (buy/sell/hold) and updates the environment"""
        self._trade(action)
        self.day += 1
        done = self.day >= len(self.df) - 1
        self.data = self.df.iloc[self.day] if not done else self.data
        reward = self._calculate_reward()
        return self._get_observation(), reward, done, {}

    def _trade(self, action):
        """Processes buy/sell actions"""
        for i in range(self.stock_dim):
            if action[i] > 0:  # Buy
                shares_to_buy = min(self.hmax, self.current_cash // self.data["close"])
                self.current_cash -= shares_to_buy * self.data["close"] * (1 + self.buy_cost_pct)
                self.num_stock_shares[i] += shares_to_buy

            elif action[i] < 0:  # Sell
                shares_to_sell = min(self.hmax, self.num_stock_shares[i])
                self.current_cash += shares_to_sell * self.data["close"] * (1 - self.sell_cost_pct)
                self.num_stock_shares[i] -= shares_to_sell

    def _calculate_reward(self):
        """Calculates reward based on portfolio value"""
        total_assets = self.current_cash + np.sum(self.num_stock_shares * self.data["close"])
        reward = total_assets - self.initial_amount
        return reward * self.reward_scaling

    def _get_observation(self):
        """Returns the current state representation"""
        # This is where the logic from cell 52 should go
        stock_data = [self.data[indicator] for indicator in self.tech_indicator_list]
        return np.array([self.current_cash] + list(self.num_stock_shares) + stock_data)

    def render(self):
        """Prints the environment state"""
        print(f"Day: {self.day}, Cash: {self.current_cash}, Holdings: {self.num_stock_shares}")

# %%
# Initialize PPO model
ppo_model = PPO("MlpPolicy", vec_env, verbose=1, learning_rate=0.0003, batch_size=64)

# Train PPO model
ppo_model.learn(total_timesteps=1000)  # Adjust timesteps as needed

# Save the trained model
ppo_model.save("ppo_stock_trading_risk")
print("PPO model training completed and saved!")
# Out:
# Using cpu device
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'returns'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-60-f9ee1451ebec> in <cell line: 0>()
#       3
#       4 # Train PPO model
# ----> 5 ppo_model.learn(total_timesteps=1000)  # Adjust timesteps as needed
#       6
#       7 # Save the trained model
#
# /usr/local/lib/python3.11/dist-packages/stable_baselines3/ppo/ppo.py in learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     309         progress_bar: bool = False,
#     310     ) -> SelfPPO:
# --> 311         return super().learn(
#     312             total_timesteps=total_timesteps,
#     313             callback=callback,
#
# /usr/local/lib/python3.11/dist-packages/stable_baselines3/common/on_policy_algorithm.py in learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     308         iteration = 0
#     309
# --> 310         total_timesteps, callback = self._setup_learn(
#     311             total_timesteps,
#     312             callback,
#
# /usr/local/lib/python3.11/dist-packages/stable_baselines3/common/base_class.py in _setup_learn(self, total_timesteps, callback, reset_num_timesteps, tb_log_name, progress_bar)
#     422         if reset_num_timesteps or self._last_obs is None:
#     423             assert self.env is not None
# --> 424             self._last_obs = self.env.reset()  # type: ignore[assignment]
#     425             self._last_episode_starts = np.ones((self.env.num_envs,), dtype=bool)
#     426             # Retrieve unnormalized observation for saving into the buffer
#
# /usr/local/lib/python3.11/dist-packages/stable_baselines3/common/vec_env/dummy_vec_env.py in reset(self)
#      76         for env_idx in range(self.num_envs):
#      77             maybe_options = {"options": self._options[env_idx]} if self._options[env_idx] else {}
# ---> 78             obs, self.reset_infos[env_idx] = self.envs[env_idx].reset(seed=self._seeds[env_idx], **maybe_options)
#      79             self._save_obs(env_idx, obs)
#      80         # Seeds and options are only used once
#
# /usr/local/lib/python3.11/dist-packages/shimmy/openai_gym_compatibility.py in reset(self, seed, options)
#     232             )
#     233
# --> 234         obs = self.gym_env.reset()
#     235
#     236         if self.render_mode == "human":
#
# <ipython-input-44-6ac3d653e98c> in reset(self)
#      38         self.num_stock_shares = np.zeros(self.stock_dim)
#      39         self.data = self.df.iloc[self.day]
# ---> 40         return self._get_observation()
#      41
#      42     def step(self, action):
#
# <ipython-input-44-6ac3d653e98c> in _get_observation(self)
#      70     def _get_observation(self):
#      71         """Returns the current state representation"""
# ---> 72         stock_data = [self.data[indicator] for indicator in self.tech_indicator_list]
#      73         return np.array([self.current_cash] + list(self.num_stock_shares) + stock_data)
#      74
#
# <ipython-input-44-6ac3d653e98c> in <listcomp>(.0)
#      70     def _get_observation(self):
#      71         """Returns the current state representation"""
# ---> 72         stock_data = [self.data[indicator] for indicator in self.tech_indicator_list]
#      73         return np.array([self.current_cash] + list(self.num_stock_shares) + stock_data)
#      74
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/series.py in __getitem__(self, key)
#    1119
#    1120         elif key_is_scalar:
# -> 1121             return self._get_value(key)
#    1122
#    1123         # Convert generator to list before going through hashable part
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1235
#    1236         # Similar to Index.get_value, but we do not fall back to positional
# -> 1237         loc = self.index.get_loc(label)
#    1238
#    1239         if is_integer(loc):
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'returns'
